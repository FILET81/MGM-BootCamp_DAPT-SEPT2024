# %% [markdown]
# # BUSINESS CASE: EUROLEAGUE CALENDAR

# %% [markdown]
# ### Welcome to Euroleague Data!
#
# In this scenario, our main goal is to obtain useful information receiving the calendar of the Euroleague Basketball
#
# ![](https://i.ytimg.com/vi/V9m_mrusffc/hqdefault.jpg)
#
# Instead of opening a CSV or an Excel File, we will start opening a Json file:

# %%
# import the recommended libraries
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import json
import numpy as np

# %%
data=json.load(open("el2023.json"))

# %% [markdown]
# #### First, let's explore the data:

# %%
type(data)       # Check that it's a dictionnaire
# Out:
# dict

# %% [markdown]
# Looking good! It is a dictionary (json style!) We will now try to use it as a DataFrame using pandas:

# %%
df=pd.DataFrame(data)

# %%
df.head()
# Out:
#                                                 data  total
# 0  {'gameCode': 304, 'season': {'name': 'EuroLeag...    306
# 1  {'gameCode': 306, 'season': {'name': 'EuroLeag...    306
# 2  {'gameCode': 303, 'season': {'name': 'EuroLeag...    306
# 3  {'gameCode': 305, 'season': {'name': 'EuroLeag...    306
# 4  {'gameCode': 301, 'season': {'name': 'EuroLeag...    306

# %% [markdown]
# ![](https://media.tenor.com/O2Tz9B1UEMsAAAAM/sxv-wtf.gif)
#
# WTF is going on? Let's explore more about this json file:

# %%
data.keys()
# Out:
# dict_keys(['data', 'total'])

# %%
data["data"]       # That's a list of dictionnaires and .keys() cannot be applied!!!!!
# Out:
# [{'gameCode': 304,
#   'season': {'name': 'EuroLeague 2023-24',
#    'code': 'E2023',
#    'alias': '2023-24',
#    'competitionCode': 'E',
#    'year': 2023,
#    'startDate': '2023-06-29T00:00:00'},
#   'group': {'id': '1c8d3521-392b-4637-8aea-7b35f797bbba',
#    'order': 1,
#    'name': 'Group Regular Season',
#    'rawName': 'Regular Season'},
#   'phaseType': {'code': 'RS',
#    'alias': 'REGULAR SEASON',
#    'name': 'Regular Season',
#    'isGroupPhase': True},
#   'round': 34,
#   'roundAlias': 'Round 34',
#   'roundName': 'Round 34',
#   'played': False,
#   'date': '2024-04-12T21:00:00',
#   'confirmedDate': True,
#   'confirmedHour': True,
#   'localTimeZone': 2,
#   'localDate': '2024-04-12T21:00:00',
#   'utcDate': '2024-04-12T19:00:00Z',
#   'local': {'club': {'code': 'ASV',
#     'name': 'LDLC ASVEL Villeurbanne',
#     'abbreviatedName': 'ASVEL',
#     'editorialName': 'ASVEL',
#     'tvCode': 'ASV',
#     'isVirtual': False,
#     'images': {'crest': 'https://media-cdn.incrowdsports.com/e33c6d1a-95ca-4dbc-b8cb-0201812104cc.png'}},
#    'score': 0,
#    'standingsScore': 0,
#    'partials': {'partials1': 0,
#     'partials2': 0,
#     'partials3': 0,
#     'partials4': 0,
#     'extraPeriods': {}}},
#   'road': {'club': {'code': 'BAR',
#     'name': 'FC Barcelona',
#     'abbreviatedName': 'Barcelona',
#     'editorialName': 'Barcelona',
#     'tvCode': 'BAR',
#     'isVirtual': False,
#     'images': {'crest': 'https://media-cdn.incrowdsports.com/35dfa503-e417-481f-963a-bdf6f013763e.png'}},
#    'score': 0,
#    'standingsScore': 0,
#    'partials': {'partials1': 0,
#     'partials2': 0,
#     'partials3': 0,
#     'partials4': 0,
#     'extraPeriods': {}}},
#   'audience': 0,
#   'audienceConfirmed': False,
#   'socialFeed': '',
#   'operationsCode': None,
#   'referee1': None,
#   'referee2': None,
#   'referee3': None,
#   'referee4': None,
#   'venue': {'name': 'LDLC ARENA',
#    'code': 'AUZ1',
#    'capacity': 12523,
#    'address': '',
#    'images': {'medium': None},
#    'active': True,
#    'notes': ''},
#   'isNeutralVenue': False,
#   'gameStatus': 'Confirmed',
#   'winner': None},
#  {'gameCode': 306,
#   'season': {'name': 'EuroLeague 2023-24',
#    'code': 'E2023',
#    'alias': '2023-24',
#    'competitionCode': 'E',
#    'year': 2023,
#    'startDate': '2023-06-29T00:00:00'},
#   'group': {'id': '1c8d3521-392b-4637-8aea-7b35f797bbba',
#    'order': 1,
#    'name': 'Group Regular Season',
#    'rawName': 'Regular Season'},
#   'phaseType': {'code': 'RS',
#    'alias': 'REGULAR SEASON',
#    'name': 'Regular Season',
#    'isGroupPhase': True},
#   'round': 34,
#   'roundAlias': 'Round 34',
#   'roundName': 'Round 34',
#   'played': False,
#   'date': '2024-04-12T20:30:00',
#   'confirmedDate': True,
#   'confirmedHour': True,
#   'localTimeZone': 2,
#   'localDate': '2024-04-12T20:30:00',
#   'utcDate': '2024-04-12T18:30:00Z',
#   'local': {'club': {'code': 'PAR',
#     'name': 'Partizan Mozzart Bet Belgrade',
#     'abbreviatedName': 'Partizan',
#     'editorialName': 'Partizan',
#     'tvCode': 'PAR',
#     'isVirtual': False,
#     'images': {'crest': 'https://media-cdn.incrowdsports.com/2681304e-77dd-4331-88b1-683078c0fb49.png'}},
#    'score': 0,
#    'standingsScore': 0,
#    'partials': {'partials1': 0,
#     'partials2': 0,
#     'partials3': 0,
#     'partials4': 0,
#     'extraPeriods': {}}},
#   'road': {'club': {'code': 'PAM',
#     'name': 'Valencia Basket',
#     'abbreviatedName': 'Valencia',
#     'editorialName': 'Valencia',
#     'tvCode': 'VBC',
#     'isVirtual': False,
#     'images': {'crest': 'https://media-cdn.incrowdsports.com/efd12730-f2ea-4830-9caa-7f2f676079c2.png'}},
#    'score': 0,
#    'standingsScore': 0,
#    'partials': {'partials1': 0,
#     'partials2': 0,
#     'partials3': 0,
#     'partials4': 0,
#     'extraPeriods': {}}},
#   'audience': 0,
#   'audienceConfirmed': False,
#   'socialFeed': '',
#   'operationsCode': None,
#   'referee1': None,
#   'referee2': None,
#   'referee3': None,
#   'referee4': None,
#   'venue': {'name': 'STARK ARENA',
#    'code': 'ATM6',
#    'capacity': 20094,
#    'address': 'Bulevar Arsenija Carnojevica 58, 11070 Belgrade - Serbia',
#    'images': {'medium': None},
#    'active': True,
#    'notes': ''},
#   'isNeutralVenue': False,
#   'gameStatus': 'Confirmed',
#   'winner': None},
#  {'gameCode': 303,
#   'season': {'name': 'EuroLeague 2023-24',
#    'code': 'E2023',
#    'alias': '2023-24',
#    'competitionCode': 'E',
#    'year': 2023,
#    'startDate': '2023-06-29T00:00:00'},
#   'group': {'id': '1c8d3521-392b-4637-8aea-7b35f797bbba',
#    'order': 1,
#    'name': 'Group Regular Season',
#    'rawName': 'Regular Season'},
#   'phaseType': {'code': 'RS',
#    'alias': 'REGULAR SEASON',
#    'name': 'Regular Season',
#    'isGroupPhase': True},
#   'round': 34,
#   'roundAlias': 'Round 34',
#   'roundName': 'Round 34',
#   'played': False,
#   'date': '2024-04-12T20:30:00',
#   'confirmedDate': True,
#   'confirmedHour': True,
#   'localTimeZone': 2,
#   'localDate': '2024-04-12T20:30:00',
#   'utcDate': '2024-04-12T18:30:00Z',
#   'local': {'club': {'code': 'VIR',
#     'name': 'Virtus Segafredo Bologna',
#     'abbreviatedName': 'Virtus',
#     'editorialName': 'Virtus',
#     'tvCode': 'VIR',
#     'isVirtual': False,
#     'images': {'crest': 'https://media-cdn.incrowdsports.com/4af5e83b-f2b5-4fba-a87c-1f85837a508a.png'}},
#    'score': 0,
#    'standingsScore': 0,
#    'partials': {'partials1': 0,
#     'partials2': 0,
#     'partials3': 0,
#     'partials4': 0,
#     'extraPeriods': {}}},
#   'road': {'club': {'code': 'BAS',
#     'name': 'Baskonia Vitoria-Gasteiz',
#     'abbreviatedName': 'Baskonia',
#     'editorialName': 'Baskonia',
#     'tvCode': 'BKN',
#     'isVirtual': False,
#     'images': {'crest': 'https://media-cdn.incrowdsports.com/e324a6af-2a72-443e-9813-8bf2d364ddab.png'}},
#    'score': 0,
#    'standingsScore': 0,
#    'partials': {'partials1': 0,
#     'partials2': 0,
#     'partials3': 0,
#     'partials4': 0,
#     'extraPeriods': {}}},
#   'audience': 0,
#   'audienceConfirmed': False,
#   'socialFeed': '',
#   'operationsCode': None,
#   'referee1': None,
#   'referee2': None,
#   'referee3': None,
#   'referee4': None,
#   'venue': {'name': 'VIRTUS SEGAFREDO ARENA',
#    'code': 'AUK1',
#    'capacity': 9768,
#    'address': '',
#    'images': {'medium': None},
#    'active': True,
#    'notes': ''},
#   'isNeutralVenue': False,
#   'gameStatus': 'Confirmed',
#   'winner': None},
#  {'gameCode': 305,
#   'season': {'name': 'EuroLeague 2023-24',
#    'code': 'E2023',
#    'alias': '2023-24',
#    'competitionCode': 'E',
#    'year': 2023,
#    'startDate': '2023-06-29T00:00:00'},
#   'group': {'id': '1c8d3521-392b-4637-8aea-7b35f797bbba',
#    'order': 1,
#    'name': 'Group Regular Season',
#    'rawName': 'Regular Season'},
#   'phaseType': {'code': 'RS',
#    'alias': 'REGULAR SEASON',
#    'name': 'Regular Season',
#    'isGroupPhase': True},
#   'round': 34,
#   'roundAlias': 'Round 34',
#   'roundName': 'Round 34',
#   'played': False,
#   'date': '2024-04-12T20:15:00',
#   'confirmedDate': True,
#   'confirmedHour': True,
#   'localTimeZone': 3,
#   'localDate': '2024-04-12T21:15:00',
#   'utcDate': '2024-04-12T18:15:00Z',
#   'local': {'club': {'code': 'OLY',
#     'name': 'Olympiacos Piraeus',
#     'abbreviatedName': 'Olympiacos',
#     'editorialName': 'Olympiacos',
#     'tvCode': 'OLY',
#     'isVirtual': False,
#     'images': {'crest': 'https://media-cdn.incrowdsports.com/789423ac-3cdf-4b89-b11c-b458aa5f59a6.png'}},
#    'score': 0,
#    'standingsScore': 0,
#    'partials': {'partials1': 0,
#     'partials2': 0,
#     'partials3': 0,
#     'partials4': 0,
#     'extraPeriods': {}}},
#   'road': {'club': {'code': 'ULK',
#     'name': 'Fenerbahce Beko Istanbul',
#     'abbreviatedName': 'Fenerbahce',
#     'editorialName': 'Fenerbahce',
#     'tvCode': 'FBB',
#     'isVirtual': False,
#     'images': {'crest': 'https://media-cdn.incrowdsports.com/0233ebbb-f3a2-49ea-837c-7fd3e661e672.png'}},
#    'score': 0,
#    'standingsScore': 0,
#    'partials': {'partials1': 0,
#     'partials2': 0,
#     'partials3': 0,
#     'partials4': 0,
#     'extraPeriods': {}}},
#   'audience': 0,
#   'audienceConfirmed': False,
#   'socialFeed': '',
#   'operationsCode': None,
#   'referee1': None,
#   'referee2': None,
#   'referee3': None,
#   'referee4': None,
#   'venue': {'name': 'PEACE AND FRIENDSHIP STADIUM',
#    'code': 'ASF6',
#    'capacity': 12700,
#    'address': 'Ethnarchou Makariou Av., Piraeus',
#    'images': {'medium': None},
#    'active': True,
#    'notes': ''},
#   'isNeutralVenue': False,
#   'gameStatus': 'Confirmed',
#   'winner': None},
#  {'gameCode': 301,
#   'season': {'name': 'EuroLeague 2023-24',
#    'code': 'E2023',
#    'alias': '2023-24',
#    'competitionCode': 'E',
#    'year': 2023,
#    'startDate': '2023-06-29T00:00:00'},
#   'group': {'id': '1c8d3521-392b-4637-8aea-7b35f797bbba',
#    'order': 1,
#    'name': 'Group Regular Season',
#    'rawName': 'Regular Season'},
#   'phaseType': {'code': 'RS',
#    'alias': 'REGULAR SEASON',
#    'name': 'Regular Season',
#    'isGroupPhase': True},
#   'round': 34,
#   'roundAlias': 'Round 34',
#   'roundName': 'Round 34',
#   'played': False,
#   'date': '2024-04-11T20:15:00',
#   'confirmedDate': True,
#   'confirmedHour': True,
#   'localTimeZone': 3,
#   'localDate': '2024-04-11T21:15:00',
#   'utcDate': '2024-04-11T18:15:00Z',
#   'local': {'club': {'code': 'PAN',
#     'name': 'Panathinaikos AKTOR Athens',
#     'abbreviatedName': 'Panathinaikos',
#     'editorialName': 'Panathinaikos',
#     'tvCode': 'PAO',
#     'isVirtual': False,
#     'images': {'crest': 'https://media-cdn.incrowdsports.com/696724ea-a92f-456e-8572-aca4ce0ff025.png'}},
#    'score': 0,
#    'standingsScore': 0,
#    'partials': {'partials1': 0,
#     'partials2': 0,
#     'partials3': 0,
#     'partials4': 0,
#     'extraPeriods': {}}},
#   'road': {'club': {'code': 'BER',
#     'name': 'ALBA Berlin',
#     'abbreviatedName': 'ALBA',
#     'editorialName': 'ALBA',
#     'tvCode': 'BER',
#     'isVirtual': False,
#     'images': {'crest': 'https://media-cdn.incrowdsports.com/ccc34858-22b0-47dc-904c-9940b0a16ff3.png'}},
#    'score': 0,
#    'standingsScore': 0,
#    'partials': {'partials1': 0,
#     'partials2': 0,
#     'partials3': 0,
#     'partials4': 0,
#     'extraPeriods': {}}},
#   'audience': 0,
#   'audienceConfirmed': False,
#   'socialFeed': '',
#   'operationsCode': None,
#   'referee1': None,
#   'referee2': None,
#   'referee3': None,
#   'referee4': None,
#   'venue': {'name': 'OAKA Altion',
#    'code': 'AUM',
#    'capacity': 18310,
#    'address': '37 Kifisias Avenue, 15123 Marousi',
#    'images': {'medium': None},
#    'active': True,
#    'notes': ''},
#   'isNeutralVenue': False,
#   'gameStatus': 'Confirmed',
#   'winner': None},
#  {'gameCode': 300,
#   'season': {'name': 'EuroLeague 2023-24',
#    'code': 'E2023',
#    'alias': '2023-24',
#    'competitionCode': 'E',
#    'year': 2023,
#    'startDate': '2023-06-29T00:00:00'},
#   'group': {'id': '1c8d3521-392b-4637-8aea-7b35f797bbba',
#    'order': 1,
#    'name': 'Group Regular Season',
#    'rawName': 'Regular Season'},
#   'phaseType': {'code': 'RS',
#    'alias': 'REGULAR SEASON',
#    'name': 'Regular Season',
#    'isGroupPhase': True},
#   'round': 34,
#   'roundAlias': 'Round 34',
#   'roundName': 'Round 34',
#   'played': False,
#   'date': '2024-04-11T20:05:00',
#   'confirmedDate': True,
#   'confirmedHour': True,
#   'localTimeZone': 3,
#   'localDate': '2024-04-11T21:05:00',
#   'utcDate': '2024-04-11T18:05:00Z',
#   'local': {'club': {'code': 'TEL',
#     'name': 'Maccabi Playtika Tel Aviv',
#     'abbreviatedName': 'Maccabi',
#     'editorialName': 'Maccabi',
#     'tvCode': 'MTA',
#     'isVirtual': False,
#     'images': {'crest': 'https://media-cdn.incrowdsports.com/5c55ef14-29df-4328-bd52-a7a64c432350.png'}},
#    'score': 0,
#    'standingsScore': 0,
#    'partials': {'partials1': 0,
#     'partials2': 0,
#     'partials3': 0,
#     'partials4': 0,
#     'extraPeriods': {}}},
#   'road': {'club': {'code': 'MIL',
#     'name': 'EA7 Emporio Armani Milan',
#     'abbreviatedName': 'Milan',
#     'editorialName': 'Milan',
#     'tvCode': 'EA7',
#     'isVirtual': False,
#     'images': {'crest': 'https://media-cdn.incrowdsports.com/8154f184-c61a-4e7f-b14d-9d802e35cb95.png'}},
#    'score': 0,
#    'standingsScore': 0,
#    'partials': {'partials1': 0,
#     'partials2': 0,
#     'partials3': 0,
#     'partials4': 0,
#     'extraPeriods': {}}},
#   'audience': 0,
#   'audienceConfirmed': False,
#   'socialFeed': '',
#   'operationsCode': None,
#   'referee1': None,
#   'referee2': None,
#   'referee3': None,
#   'referee4': None,
#   'venue': {'name': 'MENORA MIVTACHIM ARENA',
#    'code': 'AQO',
#    'capacity': 11192,
#    'address': '51, Igal Alon, 67062 Tel Aviv',
#    'images': {'medium': None},
#    'active': True,
#    'notes': ''},
#   'isNeutralVenue': False,
#   'gameStatus': 'Confirmed',
#   'winner': None},
#  {'gameCode': 298,
#   'season': {'name': 'EuroLeague 2023-24',
#    'code': 'E2023',
#    'alias': '2023-24',
#    'competitionCode': 'E',
#    'year': 2023,
#    'startDate': '2023-06-29T00:00:00'},
#   'group': {'id': '1c8d3521-392b-4637-8aea-7b35f797bbba',
#    'order': 1,
#    'name': 'Group Regular Season',
#    'rawName': 'Regular Season'},
#   'phaseType': {'code': 'RS',
#    'alias': 'REGULAR SEASON',
#    'name': 'Regular Season',
#    'isGroupPhase': True},
#   'round': 34,
#   'roundAlias': 'Round 34',
#   'roundName': 'Round 34',
#   'played': False,
#   'date': '2024-04-11T19:30:00',
#   'confirmedDate': True,
#   'confirmedHour': True,
#   'localTimeZone': 3,
#   'localDate': '2024-04-11T20:30:00',
#   'utcDate': '2024-04-11T17:30:00Z',
#   'local': {'club': {'code': 'IST',
#     'name': 'Anadolu Efes Istanbul',
#     'abbreviatedName': 'Efes',
#     'editorialName': 'Efes',
#     'tvCode': 'EFS',
#     'isVirtual': False,
#     'images': {'crest': 'https://media-cdn.incrowdsports.com/8ea8cec7-d8f7-45f4-a956-d976b5867610.png'}},
#    'score': 0,
#    'standingsScore': 0,
#    'partials': {'partials1': 0,
#     'partials2': 0,
#     'partials3': 0,
#     'partials4': 0,
#     'extraPeriods': {}}},
#   'road': {'club': {'code': 'RED',
#     'name': 'Crvena Zvezda Meridianbet Belgrade',
#     'abbreviatedName': 'Zvezda',
#     'editorialName': 'Crvena Zvezda',
#     'tvCode': 'CZV',
#     'isVirtual': False,
#     'images': {'crest': 'https://media-cdn.incrowdsports.com/d2eef4a8-62df-4fdd-9076-276004268515.png'}},
#    'score': 0,
#    'standingsScore': 0,
#    'partials': {'partials1': 0,
#     'partials2': 0,
#     'partials3': 0,
#     'partials4': 0,
#     'extraPeriods': {}}},
#   'audience': 0,
#   'audienceConfirmed': False,
#   'socialFeed': '',
#   'operationsCode': None,
#   'referee1': None,
#   'referee2': None,
#   'referee3': None,
#   'referee4': None,
#   'venue': {'name': 'SINAN ERDEM SPORTS HALL',
#    'code': 'ATK1',
#    'capacity': 15200,
#    'address': '',
#    'images': {'medium': None},
#    'active': True,
#    'notes': 'Anadolu Efes Istanbul'},
#   'isNeutralVenue': False,
#   'gameStatus': 'Confirmed',
#   'winner': None},
#  {'gameCode': 302,
#   'season': {'name': 'EuroLeague 2023-24',
#    'code': 'E2023',
#    'alias': '2023-24',
#    'competitionCode': 'E',
#    'year': 2023,
#    'startDate': '2023-06-29T00:00:00'},
#   'group': {'id': '1c8d3521-392b-4637-8aea-7b35f797bbba',
#    'order': 1,
#    'name': 'Group Regular Season',
#    'rawName': 'Regular Season'},
#   'phaseType': {'code': 'RS',
#    'alias': 'REGULAR SEASON',
#    'name': 'Regular Season',
#    'isGroupPhase': True},
#   'round': 34,
#   'roundAlias': 'Round 34',
#   'roundName': 'Round 34',
#   'played': False,
#   'date': '2024-04-11T19:00:00',
#   'confirmedDate': True,
#   'confirmedHour': True,
#   'localTimeZone': 3,
#   'localDate': '2024-04-11T20:00:00',
#   'utcDate': '2024-04-11T17:00:00Z',
#   'local': {'club': {'code': 'ZAL',
#     'name': 'Zalgiris Kaunas',
#     'abbreviatedName': 'Zalgiris',
#     'editorialName': 'Zalgiris',
#     'tvCode': 'ZAL',
#     'isVirtual': False,
#     'images': {'crest': 'https://media-cdn.incrowdsports.com/0aa09358-3847-4c4e-b228-3582ee4e536d.png'}},
#    'score': 0,
#    'standingsScore': 0,
#    'partials': {'partials1': 0,
#     'partials2': 0,
#     'partials3': 0,
#     'partials4': 0,
#     'extraPeriods': {}}},
#   'road': {'club': {'code': 'MAD',
#     'name': 'Real Madrid',
#     'abbreviatedName': 'Real',
#     'editorialName': 'Real',
#     'tvCode': 'RMB',
#     'isVirtual': False,
#     'images': {'crest': 'https://media-cdn.incrowdsports.com/1a3e1404-4f6f-4ede-9d8b-30eee7cb51b4.png'}},
#    'score': 0,
#    'standingsScore': 0,
#    'partials': {'partials1': 0,
#     'partials2': 0,
#     'partials3': 0,
#     'partials4': 0,
#     'extraPeriods': {}}},
#   'audience': 0,
#   'audienceConfirmed': False,
#   'socialFeed': '',
#   'operationsCode': None,
#   'referee1': None,
#   'referee2': None,
#   'referee3': None,
#   'referee4': None,
#   'venue': {'name': 'ZALGIRIO ARENA',
#    'code': 'ATJ',
#    'capacity': 15415,
#    'address': 'Karaliaus Mindaugo Av. 50, 44287 Kaunas',
#    'images': {'medium': None},
#    'active': True,
#    'notes': ''},
#   'isNeutralVenue': False,
#   'gameStatus': 'Confirmed',
#   'winner': None},
#  {'gameCode': 299,
#   'season': {'name': 'EuroLeague 2023-24',
#    'code': 'E2023',
#    'alias': '2023-24',
#    'competitionCode': 'E',
#    'year': 2023,
#    'startDate': '2023-06-29T00:00:00'},
#   'group': {'id': '1c8d3521-392b-4637-8aea-7b35f797bbba',
#    'order': 1,
#    'name': 'Group Regular Season',
#    'rawName': 'Regular Season'},
#   'phaseType': {'code': 'RS',
#    'alias': 'REGULAR SEASON',
#    'name': 'Regular Season',
#    'isGroupPhase': True},
#   'round': 34,
#   'roundAlias': 'Round 34',
#   'roundName': 'Round 34',
#   'played': False,
#   'date': '2024-04-11T19:00:00',
#   'confirmedDate': True,
#   'confirmedHour': True,
#   'localTimeZone': 2,
#   'localDate': '2024-04-11T19:00:00',
#   'utcDate': '2024-04-11T17:00:00Z',
#   'local': {'club': {'code': 'MCO',
#     'name': 'AS Monaco',
#     'abbreviatedName': 'Monaco',
#     'editorialName': 'Monaco',
#     'tvCode': 'ASM',
#     'isVirtual': False,
#     'images': {'crest': 'https://media-cdn.incrowdsports.com/89ed276a-2ba3-413f-8ea2-b3be209ca129.png'}},
#    'score': 0,
#    'standingsScore': 0,
#    'partials': {'partials1': 0,
#     'partials2': 0,
#     'partials3': 0,
#     'partials4': 0,
#     'extraPeriods': {}}},
#   'road': {'club': {'code': 'MUN',
#     'name': 'FC Bayern Munich',
#     'abbreviatedName': 'Bayern',
#     'editorialName': 'Bayern',
#     'tvCode': 'BAY',
#     'isVirtual': False,
#     'images': {'crest': 'https://media-cdn.incrowdsports.com/817b0e58-d595-4b09-ab0b-1e7cc26249ff.png'}},
#    'score': 0,
#    'standingsScore': 0,
#    'partials': {'partials1': 0,
#     'partials2': 0,
#     'partials3': 0,
#     'partials4': 0,
#     'extraPeriods': {}}},
#   'audience': 0,
#   'audienceConfirmed': False,
#   'socialFeed': '',
#   'operationsCode': None,
#   'referee1': None,
#   'referee2': None,
#   'referee3': None,
#   'referee4': None,
#   'venue': {'name': 'SALLE GASTON MEDECIN',
#    'code': 'AUR2',
#    'capacity': 5000,
#    'address': '3 et 7 Avenue des Castelans, 98000, Monaco',
#    'images': {'medium': None},
#    'active': True,
#    'notes': ''},
#   'isNeutralVenue': False,
#   'gameStatus': 'Confirmed',
#   'winner': None},
#  {'gameCode': 297,
#   'season': {'name': 'EuroLeague 2023-24',
#    'code': 'E2023',
#    'alias': '2023-24',
#    'competitionCode': 'E',
#    'year': 2023,
#    'startDate': '2023-06-29T00:00:00'},
#   'group': {'id': '1c8d3521-392b-4637-8aea-7b35f797bbba',
#    'order': 1,
#    'name': 'Group Regular Season',
#    'rawName': 'Regular Season'},
#   'phaseType': {'code': 'RS',
#    'alias': 'REGULAR SEASON',
#    'name': 'Regular Season',
#    'isGroupPhase': True},
#   'round': 33,
#   'roundAlias': 'Round 33',
#   'roundName': 'Round 33',
#   'played': False,
#   'date': '2024-04-05T20:30:00',
#   'confirmedDate': True,
#   'confirmedHour': True,
#   'localTimeZone': 2,
#   'localDate': '2024-04-05T20:30:00',
#   'utcDate': '2024-04-05T18:30:00Z',
#   'local': {'club': {'code': 'MAD',
#     'name': 'Real Madrid',
#     'abbreviatedName': 'Real',
#     'editorialName': 'Real',
#     'tvCode': 'RMB',
#     'isVirtual': False,
#     'images': {'crest': 'https://media-cdn.incrowdsports.com/1a3e1404-4f6f-4ede-9d8b-30eee7cb51b4.png'}},
#    'score': 0,
#    'standingsScore': 0,
#    'partials': {'partials1': 0,
#     'partials2': 0,
#     'partials3': 0,
#     'partials4': 0,
#     'extraPeriods': {}}},
#   'road': {'club': {'code': 'BAS',
#     'name': 'Baskonia Vitoria-Gasteiz',
#     'abbreviatedName': 'Baskonia',
#     'editorialName': 'Baskonia',
#     'tvCode': 'BKN',
#     'isVirtual': False,
#     'images': {'crest': 'https://media-cdn.incrowdsports.com/e324a6af-2a72-443e-9813-8bf2d364ddab.png'}},
#    'score': 0,
#    'standingsScore': 0,
#    'partials': {'partials1': 0,
#     'partials2': 0,
#     'partials3': 0,
#     'partials4': 0,
#     'extraPeriods': {}}},
#   'audience': 0,
#   'audienceConfirmed': False,
#   'socialFeed': '',
#   'operationsCode': None,
#   'referee1': None,
#   'referee2': None,
#   'referee3': None,
#   'referee4': None,
#   'venue': {'name': 'WIZINK CENTER',
#    'code': 'ATI',
#    'capacity': 13109,
#    'address': 'Avenida de Felipe II 1, 28009, Madrid',
#    'images': {'medium': None},
#    'active': True,
#    'notes': ''},
#   'isNeutralVenue': False,
#   'gameStatus': 'Confirmed',
#   'winner': None},
#  {'gameCode': 295,
#   'season': {'name': 'EuroLeague 2023-24',
#    'code': 'E2023',
#    'alias': '2023-24',
#    'competitionCode': 'E',
#    'year': 2023,
#    'startDate': '2023-06-29T00:00:00'},
#   'group': {'id': '1c8d3521-392b-4637-8aea-7b35f797bbba',
#    'order': 1,
#    'name': 'Group Regular Season',
#    'rawName': 'Regular Season'},
#   'phaseType': {'code': 'RS',
#    'alias': 'REGULAR SEASON',
#    'name': 'Regular Season',
#    'isGroupPhase': True},
#   'round': 33,
#   'roundAlias': 'Round 33',
#   'roundName': 'Round 33',
#   'played': False,
#   'date': '2024-04-05T20:30:00',
#   'confirmedDate': True,
#   'confirmedHour': True,
#   'localTimeZone': 2,
#   'localDate': '2024-04-05T20:30:00',
#   'utcDate': '2024-04-05T18:30:00Z',
#   'local': {'club': {'code': 'MUN',
#     'name': 'FC Bayern Munich',
#     'abbreviatedName': 'Bayern',
#     'editorialName': 'Bayern',
#     'tvCode': 'BAY',
#     'isVirtual': False,
#     'images': {'crest': 'https://media-cdn.incrowdsports.com/817b0e58-d595-4b09-ab0b-1e7cc26249ff.png'}},
#    'score': 0,
#    'standingsScore': 0,
#    'partials': {'partials1': 0,
#     'partials2': 0,
#     'partials3': 0,
#     'partials4': 0,
#     'extraPeriods': {}}},
#   'road': {'club': {'code': 'PAN',
#     'name': 'Panathinaikos AKTOR Athens',
#     'abbreviatedName': 'Panathinaikos',
#     'editorialName': 'Panathinaikos',
#     'tvCode': 'PAO',
#     'isVirtual': False,
#     'images': {'crest': 'https://media-cdn.incrowdsports.com/696724ea-a92f-456e-8572-aca4ce0ff025.png'}},
#    'score': 0,
#    'standingsScore': 0,
#    'partials': {'partials1': 0,
#     'partials2': 0,
#     'partials3': 0,
#     'partials4': 0,
#     'extraPeriods': {}}},
#   'audience': 0,
#   'audienceConfirmed': False,
#   'socialFeed': '',
#   'operationsCode': None,
#   'referee1': None,
#   'referee2': None,
#   'referee3': None,
#   'referee4': None,
#   'venue': {'name': 'BMW PARK',
#    'code': 'AMV1',
#    'capacity': 6534,
#    'address': 'Grasweg 74, 81373 Munich',
#    'images': {'medium': None},
#    'active': True,
#    'notes': ''},
#   'isNeutralVenue': False,
#   'gameStatus': 'Confirmed',
#   'winner': None},
#  {'gameCode': 294,
#   'season': {'name': 'EuroLeague 2023-24',
#    'code': 'E2023',
#    'alias': '2023-24',
#    'competitionCode': 'E',
#    'year': 2023,
#    'startDate': '2023-06-29T00:00:00'},
#   'group': {'id': '1c8d3521-392b-4637-8aea-7b35f797bbba',
#    'order': 1,
#    'name': 'Group Regular Season',
#    'rawName': 'Regular Season'},
#   'phaseType': {'code': 'RS',
#    'alias': 'REGULAR SEASON',
#    'name': 'Regular Season',
#    'isGroupPhase': True},
#   'round': 33,
#   'roundAlias': 'Round 33',
#   'roundName': 'Round 33',
#   'played': False,
#   'date': '2024-04-05T20:30:00',
#   'confirmedDate': True,
#   'confirmedHour': True,
#   'localTimeZone': 2,
#   'localDate': '2024-04-05T20:30:00',
#   'utcDate': '2024-04-05T18:30:00Z',
#   'local': {'club': {'code': 'MIL',
#     'name': 'EA7 Emporio Armani Milan',
#     'abbreviatedName': 'Milan',
#     'editorialName': 'Milan',
#     'tvCode': 'EA7',
#     'isVirtual': False,
#     'images': {'crest': 'https://media-cdn.incrowdsports.com/8154f184-c61a-4e7f-b14d-9d802e35cb95.png'}},
#    'score': 0,
#    'standingsScore': 0,
#    'partials': {'partials1': 0,
#     'partials2': 0,
#     'partials3': 0,
#     'partials4': 0,
#     'extraPeriods': {}}},
#   'road': {'club': {'code': 'VIR',
#     'name': 'Virtus Segafredo Bologna',
#     'abbreviatedName': 'Virtus',
#     'editorialName': 'Virtus',
#     'tvCode': 'VIR',
#     'isVirtual': False,
#     'images': {'crest': 'https://media-cdn.incrowdsports.com/4af5e83b-f2b5-4fba-a87c-1f85837a508a.png'}},
#    'score': 0,
#    'standingsScore': 0,
#    'partials': {'partials1': 0,
#     'partials2': 0,
#     'partials3': 0,
#     'partials4': 0,
#     'extraPeriods': {}}},
#   'audience': 0,
#   'audienceConfirmed': False,
#   'socialFeed': '',
#   'operationsCode': None,
#   'referee1': None,
#   'referee2': None,
#   'referee3': None,
#   'referee4': None,
#   'venue': {'name': 'FORUM',
#    'code': 'ASX6',
#    'capacity': 12657,
#    'address': 'Via G. Di Vittorio 6, 20090 Assago',
#    'images': {'medium': None},
#    'active': True,
#    'notes': ''},
#   'isNeutralVenue': False,
#   'gameStatus': 'Confirmed',
#   'winner': None},
#  {'gameCode': 296,
#   'season': {'name': 'EuroLeague 2023-24',
#    'code': 'E2023',
#    'alias': '2023-24',
#    'competitionCode': 'E',
#    'year': 2023,
#    'startDate': '2023-06-29T00:00:00'},
#   'group': {'id': '1c8d3521-392b-4637-8aea-7b35f797bbba',
#    'order': 1,
#    'name': 'Group Regular Season',
#    'rawName': 'Regular Season'},
#   'phaseType': {'code': 'RS',
#    'alias': 'REGULAR SEASON',
#    'name': 'Regular Season',
#    'isGroupPhase': True},
#   'round': 33,
#   'roundAlias': 'Round 33',
#   'roundName': 'Round 33',
#   'played': False,
#   'date': '2024-04-05T19:45:00',
#   'confirmedDate': True,
#   'confirmedHour': True,
#   'localTimeZone': 3,
#   'localDate': '2024-04-05T20:45:00',
#   'utcDate': '2024-04-05T17:45:00Z',
#   'local': {'club': {'code': 'ULK',
#     'name': 'Fenerbahce Beko Istanbul',
#     'abbreviatedName': 'Fenerbahce',
#     'editorialName': 'Fenerbahce',
#     'tvCode': 'FBB',
#     'isVirtual': False,
#     'images': {'crest': 'https://media-cdn.incrowdsports.com/0233ebbb-f3a2-49ea-837c-7fd3e661e672.png'}},
#    'score': 0,
#    'standingsScore': 0,
#    'partials': {'partials1': 0,
#     'partials2': 0,
#     'partials3': 0,
#     'partials4': 0,
#     'extraPeriods': {}}},
#   'road': {'club': {'code': 'IST',
#     'name': 'Anadolu Efes Istanbul',
#     'abbreviatedName': 'Efes',
#     'editorialName': 'Efes',
#     'tvCode': 'EFS',
#     'isVirtual': False,
#     'images': {'crest': 'https://media-cdn.incrowdsports.com/8ea8cec7-d8f7-45f4-a956-d976b5867610.png'}},
#    'score': 0,
#    'standingsScore': 0,
#    'partials': {'partials1': 0,
#     'partials2': 0,
#     'partials3': 0,
#     'partials4': 0,
#     'extraPeriods': {}}},
#   'audience': 0,
#   'audienceConfirmed': False,
#   'socialFeed': '',
#   'operationsCode': None,
#   'referee1': None,
#   'referee2': None,
#   'referee3': None,
#   'referee4': None,
#   'venue': {'name': 'ULKER SPORTS AND EVENT HALL',
#    'code': 'AMY3',
#    'capacity': 13113,
#    'address': 'Barbaros Mah. Ihlamur Sok. Batı Ataşehir, 34764 Istanbul',
#    'images': {'medium': None},
#    'active': True,
#    'notes': ''},
#   'isNeutralVenue': False,
#   'gameStatus': 'Confirmed',
#   'winner': None},
#  {'gameCode': 293,
#   'season': {'name': 'EuroLeague 2023-24',
#    'code': 'E2023',
#    'alias': '2023-24',
#    'competitionCode': 'E',
#    'year': 2023,
#    'startDate': '2023-06-29T00:00:00'},
#   'group': {'id': '1c8d3521-392b-4637-8aea-7b35f797bbba',
#    'order': 1,
#    'name': 'Group Regular Season',
#    'rawName': 'Regular Season'},
#   'phaseType': {'code': 'RS',
#    'alias': 'REGULAR SEASON',
#    'name': 'Regular Season',
#    'isGroupPhase': True},
#   'round': 33,
#   'roundAlias': 'Round 33',
#   'roundName': 'Round 33',
#   'played': False,
#   'date': '2024-04-04T20:45:00',
#   'confirmedDate': True,
#   'confirmedHour': True,
#   'localTimeZone': 2,
#   'localDate': '2024-04-04T20:45:00',
#   'utcDate': '2024-04-04T18:45:00Z',
#   'local': {'club': {'code': 'PAM',
#     'name': 'Valencia Basket',
#     'abbreviatedName': 'Valencia',
#     'editorialName': 'Valencia',
#     'tvCode': 'VBC',
#     'isVirtual': False,
#     'images': {'crest': 'https://media-cdn.incrowdsports.com/efd12730-f2ea-4830-9caa-7f2f676079c2.png'}},
#    'score': 0,
#    'standingsScore': 0,
#    'partials': {'partials1': 0,
#     'partials2': 0,
#     'partials3': 0,
#     'partials4': 0,
#     'extraPeriods': {}}},
#   'road': {'club': {'code': 'ASV',
#     'name': 'LDLC ASVEL Villeurbanne',
#     'abbreviatedName': 'ASVEL',
#     'editorialName': 'ASVEL',
#     'tvCode': 'ASV',
#     'isVirtual': False,
#     'images': {'crest': 'https://media-cdn.incrowdsports.com/e33c6d1a-95ca-4dbc-b8cb-0201812104cc.png'}},
#    'score': 0,
#    'standingsScore': 0,
#    'partials': {'partials1': 0,
#     'partials2': 0,
#     'partials3': 0,
#     'partials4': 0,
#     'extraPeriods': {}}},
#   'audience': 0,
#   'audienceConfirmed': False,
#   'socialFeed': '',
#   'operationsCode': None,
#   'referee1': None,
#   'referee2': None,
#   'referee3': None,
#   'referee4': None,
#   'venue': {'name': 'PABELLON FUENTE DE SAN LUIS',
#    'code': 'APQ2',
#    'capacity': 8500,
#    'address': 'Av. Hermanos Maristas 16<br> 46013 Valencia',
#    'images': {'medium': None},
#    'active': True,
#    'notes': ''},
#   'isNeutralVenue': False,
#   'gameStatus': 'Confirmed',
#   'winner': None},
#  {'gameCode': 292,
#   'season': {'name': 'EuroLeague 2023-24',
#    'code': 'E2023',
#    'alias': '2023-24',
#    'competitionCode': 'E',
#    'year': 2023,
#    'startDate': '2023-06-29T00:00:00'},
#   'group': {'id': '1c8d3521-392b-4637-8aea-7b35f797bbba',
#    'order': 1,
#    'name': 'Group Regular Season',
#    'rawName': 'Regular Season'},
#   'phaseType': {'code': 'RS',
#    'alias': 'REGULAR SEASON',
#    'name': 'Regular Season',
#    'isGroupPhase': True},
#   'round': 33,
#   'roundAlias': 'Round 33',
#   'roundName': 'Round 33',
#   'played': False,
#   'date': '2024-04-04T20:30:00',
#   'confirmedDate': True,
#   'confirmedHour': True,
#   'localTimeZone': 2,
#   'localDate': '2024-04-04T20:30:00',
#   'utcDate': '2024-04-04T18:30:00Z',
#   'local': {'club': {'code': 'BAR',
#     'name': 'FC Barcelona',
#     'abbreviatedName': 'Barcelona',
#     'editorialName': 'Barcelona',
#     'tvCode': 'BAR',
#     'isVirtual': False,
#     'images': {'crest': 'https://media-cdn.incrowdsports.com/35dfa503-e417-481f-963a-bdf6f013763e.png'}},
#    'score': 0,
#    'standingsScore': 0,
#    'partials': {'partials1': 0,
#     'partials2': 0,
#     'partials3': 0,
#     'partials4': 0,
#     'extraPeriods': {}}},
#   'road': {'club': {'code': 'TEL',
#     'name': 'Maccabi Playtika Tel Aviv',
#     'abbreviatedName': 'Maccabi',
#     'editorialName': 'Maccabi',
#     'tvCode': 'MTA',
#     'isVirtual': False,
#     'images': {'crest': 'https://media-cdn.incrowdsports.com/5c55ef14-29df-4328-bd52-a7a64c432350.png'}},
#    'score': 0,
#    'standingsScore': 0,
#    'partials': {'partials1': 0,
#     'partials2': 0,
#     'partials3': 0,
#     'partials4': 0,
#     'extraPeriods': {}}},
#   'audience': 0,
#   'audienceConfirmed': False,
#   'socialFeed': '',
#   'operationsCode': None,
#   'referee1': None,
#   'referee2': None,
#   'referee3': None,
#   'referee4': None,
#   'venue': {'name': 'PALAU BLAUGRANA',
#    'code': 'AMH3',
#    'capacity': 7786,
#    'address': 'Aristides Maillol Av S/N, 08028 Barcelona',
#    'images': {'medium': None},
#    'active': True,
#    'notes': ''},
#   'isNeutralVenue': False,
#   'gameStatus': 'Confirmed',
#   'winner': None},
#  {'gameCode': 289,
#   'season': {'name': 'EuroLeague 2023-24',
#    'code': 'E2023',
#    'alias': '2023-24',
#    'competitionCode': 'E',
#    'year': 2023,
#    'startDate': '2023-06-29T00:00:00'},
#   'group': {'id': '1c8d3521-392b-4637-8aea-7b35f797bbba',
#    'order': 1,
#    'name': 'Group Regular Season',
#    'rawName': 'Regular Season'},
#   'phaseType': {'code': 'RS',
#    'alias': 'REGULAR SEASON',
#    'name': 'Regular Season',
#    'isGroupPhase': True},
#   'round': 33,
#   'roundAlias': 'Round 33',
#   'roundName': 'Round 33',
#   'played': False,
#   'date': '2024-04-04T20:30:00',
#   'confirmedDate': True,
#   'confirmedHour': True,
#   'localTimeZone': 2,
#   'localDate': '2024-04-04T20:30:00',
#   'utcDate': '2024-04-04T18:30:00Z',
#   'local': {'club': {'code': 'BER',
#     'name': 'ALBA Berlin',
#     'abbreviatedName': 'ALBA',
#     'editorialName': 'ALBA',
#     'tvCode': 'BER',
#     'isVirtual': False,
#     'images': {'crest': 'https://media-cdn.incrowdsports.com/ccc34858-22b0-47dc-904c-9940b0a16ff3.png'}},
#    'score': 0,
#    'standingsScore': 0,
#    'partials': {'partials1': 0,
#     'partials2': 0,
#     'partials3': 0,
#     'partials4': 0,
#     'extraPeriods': {}}},
#   'road': {'club': {'code': 'PAR',
#     'name': 'Partizan Mozzart Bet Belgrade',
#     'abbreviatedName': 'Partizan',
#     'editorialName': 'Partizan',
#     'tvCode': 'PAR',
#     'isVirtual': False,
#     'images': {'crest': 'https://media-cdn.incrowdsports.com/2681304e-77dd-4331-88b1-683078c0fb49.png'}},
#    'score': 0,
#    'standingsScore': 0,
#    'partials': {'partials1': 0,
#     'partials2': 0,
#     'partials3': 0,
#     'partials4': 0,
#     'extraPeriods': {}}},
#   'audience': 0,
#   'audienceConfirmed': False,
#   'socialFeed': '',
#   'operationsCode': None,
#   'referee1': None,
#   'referee2': None,
#   'referee3': None,
#   'referee4': None,
#   'venue': {'name': 'MERCEDES-BENZ ARENA',
#    'code': 'ASY',
#    'capacity': 14500,
#    'address': 'Mercedes-Platz 1, Berlin',
#    'images': {'medium': None},
#    'active': True,
#    'notes': ''},
#   'isNeutralVenue': False,
#   'gameStatus': 'Confirmed',
#   'winner': None},
#  {'gameCode': 291,
#   'season': {'name': 'EuroLeague 2023-24',
#    'code': 'E2023',
#    'alias': '2023-24',
#    'competitionCode': 'E',
#    'year': 2023,
#    'startDate': '2023-06-29T00:00:00'},
#   'group': {'id': '1c8d3521-392b-4637-8aea-7b35f797bbba',
#    'order': 1,
#    'name': 'Group Regular Season',
#    'rawName': 'Regular Season'},
#   'phaseType': {'code': 'RS',
#    'alias': 'REGULAR SEASON',
#    'name': 'Regular Season',
#    'isGroupPhase': True},
#   'round': 33,
#   'roundAlias': 'Round 33',
#   'roundName': 'Round 33',
#   'played': False,
#   'date': '2024-04-04T19:00:00',
#   'confirmedDate': True,
#   'confirmedHour': True,
#   'localTimeZone': 2,
#   'localDate': '2024-04-04T19:00:00',
#   'utcDate': '2024-04-04T17:00:00Z',
#   'local': {'club': {'code': 'RED',
#     'name': 'Crvena Zvezda Meridianbet Belgrade',
#     'abbreviatedName': 'Zvezda',
#     'editorialName': 'Crvena Zvezda',
#     'tvCode': 'CZV',
#     'isVirtual': False,
#     'images': {'crest': 'https://media-cdn.incrowdsports.com/d2eef4a8-62df-4fdd-9076-276004268515.png'}},
#    'score': 0,
#    'standingsScore': 0,
#    'partials': {'partials1': 0,
#     'partials2': 0,
#     'partials3': 0,
#     'partials4': 0,
#     'extraPeriods': {}}},
#   'road': {'club': {'code': 'OLY',
#     'name': 'Olympiacos Piraeus',
#     'abbreviatedName': 'Olympiacos',
#     'editorialName': 'Olympiacos',
#     'tvCode': 'OLY',
#     'isVirtual': False,
#     'images': {'crest': 'https://media-cdn.incrowdsports.com/789423ac-3cdf-4b89-b11c-b458aa5f59a6.png'}},
#    'score': 0,
#    'standingsScore': 0,
#    'partials': {'partials1': 0,
#     'partials2': 0,
#     'partials3': 0,
#     'partials4': 0,
#     'extraPeriods': {}}},
#   'audience': 0,
#   'audienceConfirmed': False,
#   'socialFeed': '',
#   'operationsCode': None,
#   'referee1': None,
#   'referee2': None,
#   'referee3': None,
#   'referee4': None,
#   'venue': {'name': 'STARK ARENA',
#    'code': 'ATM6',
#    'capacity': 20094,
#    'address': 'Bulevar Arsenija Carnojevica 58, 11070 Belgrade - Serbia',
#    'images': {'medium': None},
#    'active': True,
#    'notes': ''},
#   'isNeutralVenue': False,
#   'gameStatus': 'Confirmed',
#   'winner': None},
#  {'gameCode': 290,
#   'season': {'name': 'EuroLeague 2023-24',
#    'code': 'E2023',
#    'alias': '2023-24',
#    'competitionCode': 'E',
#    'year': 2023,
#    'startDate': '2023-06-29T00:00:00'},
#   'group': {'id': '1c8d3521-392b-4637-8aea-7b35f797bbba',
#    'order': 1,
#    'name': 'Group Regular Season',
#    'rawName': 'Regular Season'},
#   'phaseType': {'code': 'RS',
#    'alias': 'REGULAR SEASON',
#    'name': 'Regular Season',
#    'isGroupPhase': True},
#   'round': 33,
#   'roundAlias': 'Round 33',
#   'roundName': 'Round 33',
#   'played': False,
#   'date': '2024-04-04T19:00:00',
#   'confirmedDate': True,
#   'confirmedHour': True,
#   'localTimeZone': 2,
#   'localDate': '2024-04-04T19:00:00',
#   'utcDate': '2024-04-04T17:00:00Z',
#   'local': {'club': {'code': 'MCO',
#     'name': 'AS Monaco',
#     'abbreviatedName': 'Monaco',
#     'editorialName': 'Monaco',
#     'tvCode': 'ASM',
#     'isVirtual': False,
#     'images': {'crest': 'https://media-cdn.incrowdsports.com/89ed276a-2ba3-413f-8ea2-b3be209ca129.png'}},
#    'score': 0,
#    'standingsScore': 0,
#    'partials': {'partials1': 0,
#     'partials2': 0,
#     'partials3': 0,
#     'partials4': 0,
#     'extraPeriods': {}}},
#   'road': {'club': {'code': 'ZAL',
#     'name': 'Zalgiris Kaunas',
#     'abbreviatedName': 'Zalgiris',
#     'editorialName': 'Zalgiris',
#     'tvCode': 'ZAL',
#     'isVirtual': False,
#     'images': {'crest': 'https://media-cdn.incrowdsports.com/0aa09358-3847-4c4e-b228-3582ee4e536d.png'}},
#    'score': 0,
#    'standingsScore': 0,
#    'partials': {'partials1': 0,
#     'partials2': 0,
#     'partials3': 0,
#     'partials4': 0,
#     'extraPeriods': {}}},
#   'audience': 0,
#   'audienceConfirmed': False,
#   'socialFeed': '',
#   'operationsCode': None,
#   'referee1': None,
#   'referee2': None,
#   'referee3': None,
#   'referee4': None,
#   'venue': {'name': 'SALLE GASTON MEDECIN',
#    'code': 'AUR2',
#    'capacity': 5000,
#    'address': '3 et 7 Avenue des Castelans, 98000, Monaco',
#    'images': {'medium': None},
#    'active': True,
#    'notes': ''},
#   'isNeutralVenue': False,
#   'gameStatus': 'Confirmed',
#   'winner': None},
#  {'gameCode': 288,
#   'season': {'name': 'EuroLeague 2023-24',
#    'code': 'E2023',
#    'alias': '2023-24',
#    'competitionCode': 'E',
#    'year': 2023,
#    'startDate': '2023-06-29T00:00:00'},
#   'group': {'id': '1c8d3521-392b-4637-8aea-7b35f797bbba',
#    'order': 1,
#    'name': 'Group Regular Season',
#    'rawName': 'Regular Season'},
#   'phaseType': {'code': 'RS',
#    'alias': 'REGULAR SEASON',
#    'name': 'Regular Season',
#    'isGroupPhase': True},
#   'round': 32,
#   'roundAlias': 'Round 32',
#   'roundName': 'Round 32',
#   'played': False,
#   'date': '2024-03-29T20:30:00',
#   'confirmedDate': True,
#   'confirmedHour': True,
#   'localTimeZone': 1,
#   'localDate': '2024-03-29T20:30:00',
#   'utcDate': '2024-03-29T19:30:00Z',
#   'local': {'club': {'code': 'VIR',
#     'name': 'Virtus Segafredo Bologna',
#     'abbreviatedName': 'Virtus',
#     'editorialName': 'Virtus',
#     'tvCode': 'VIR',
#     'isVirtual': False,
#     'images': {'crest': 'https://media-cdn.incrowdsports.com/4af5e83b-f2b5-4fba-a87c-1f85837a508a.png'}},
#    'score': 0,
#    'standingsScore': 0,
#    'partials': {'partials1': 0,
#     'partials2': 0,
#     'partials3': 0,
#     'partials4': 0,
#     'extraPeriods': {}}},
#   'road': {'club': {'code': 'PAN',
#     'name': 'Panathinaikos AKTOR Athens',
#     'abbreviatedName': 'Panathinaikos',
#     'editorialName': 'Panathinaikos',
#     'tvCode': 'PAO',
#     'isVirtual': False,
#     'images': {'crest': 'https://media-cdn.incrowdsports.com/696724ea-a92f-456e-8572-aca4ce0ff025.png'}},
#    'score': 0,
#    'standingsScore': 0,
#    'partials': {'partials1': 0,
#     'partials2': 0,
#     'partials3': 0,
#     'partials4': 0,
#     'extraPeriods': {}}},
#   'audience': 0,
#   'audienceConfirmed': False,
#   'socialFeed': '',
#   'operationsCode': None,
#   'referee1': None,
#   'referee2': None,
#   'referee3': None,
#   'referee4': None,
#   'venue': {'name': 'VIRTUS SEGAFREDO ARENA',
#    'code': 'AUK1',
#    'capacity': 9768,
#    'address': '',
#    'images': {'medium': None},
#    'active': True,
#    'notes': ''},
#   'isNeutralVenue': False,
#   'gameStatus': 'Confirmed',
#   'winner': None},
#  {'gameCode': 287,
#   'season': {'name': 'EuroLeague 2023-24',
#    'code': 'E2023',
#    'alias': '2023-24',
#    'competitionCode': 'E',
#    'year': 2023,
#    'startDate': '2023-06-29T00:00:00'},
#   'group': {'id': '1c8d3521-392b-4637-8aea-7b35f797bbba',
#    'order': 1,
#    'name': 'Group Regular Season',
#    'rawName': 'Regular Season'},
#   'phaseType': {'code': 'RS',
#    'alias': 'REGULAR SEASON',
#    'name': 'Regular Season',
#    'isGroupPhase': True},
#   'round': 32,
#   'roundAlias': 'Round 32',
#   'roundName': 'Round 32',
#   'played': False,
#   'date': '2024-03-29T20:30:00',
#   'confirmedDate': True,
#   'confirmedHour': True,
#   'localTimeZone': 1,
#   'localDate': '2024-03-29T20:30:00',
#   'utcDate': '2024-03-29T19:30:00Z',
#   'local': {'club': {'code': 'MAD',
#     'name': 'Real Madrid',
#     'abbreviatedName': 'Real',
#     'editorialName': 'Real',
#     'tvCode': 'RMB',
#     'isVirtual': False,
#     'images': {'crest': 'https://media-cdn.incrowdsports.com/1a3e1404-4f6f-4ede-9d8b-30eee7cb51b4.png'}},
#    'score': 0,
#    'standingsScore': 0,
#    'partials': {'partials1': 0,
#     'partials2': 0,
#     'partials3': 0,
#     'partials4': 0,
#     'extraPeriods': {}}},
#   'road': {'club': {'code': 'RED',
#     'name': 'Crvena Zvezda Meridianbet Belgrade',
#     'abbreviatedName': 'Zvezda',
#     'editorialName': 'Crvena Zvezda',
#     'tvCode': 'CZV',
#     'isVirtual': False,
#     'images': {'crest': 'https://media-cdn.incrowdsports.com/d2eef4a8-62df-4fdd-9076-276004268515.png'}},
#    'score': 0,
#    'standingsScore': 0,
#    'partials': {'partials1': 0,
#     'partials2': 0,
#     'partials3': 0,
#     'partials4': 0,
#     'extraPeriods': {}}},
#   'audience': 0,
#   'audienceConfirmed': False,
#   'socialFeed': '',
#   'operationsCode': None,
#   'referee1': None,
#   'referee2': None,
#   'referee3': None,
#   'referee4': None,
#   'venue': {'name': 'WIZINK CENTER',
#    'code': 'ATI',
#    'capacity': 13109,
#    'address': 'Avenida de Felipe II 1, 28009, Madrid',
#    'images': {'medium': None},
#    'active': True,
#    'notes': ''},
#   'isNeutralVenue': False,
#   'gameStatus': 'Confirmed',
#   'winner': None},
#  {'gameCode': 286,
#   'season': {'name': 'EuroLeague 2023-24',
#    'code': 'E2023',
#    'alias': '2023-24',
#    'competitionCode': 'E',
#    'year': 2023,
#    'startDate': '2023-06-29T00:00:00'},
#   'group': {'id': '1c8d3521-392b-4637-8aea-7b35f797bbba',
#    'order': 1,
#    'name': 'Group Regular Season',
#    'rawName': 'Regular Season'},
#   'phaseType': {'code': 'RS',
#    'alias': 'REGULAR SEASON',
#    'name': 'Regular Season',
#    'isGroupPhase': True},
#   'round': 32,
#   'roundAlias': 'Round 32',
#   'roundName': 'Round 32',
#   'played': False,
#   'date': '2024-03-29T18:45:00',
#   'confirmedDate': True,
#   'confirmedHour': True,
#   'localTimeZone': 3,
#   'localDate': '2024-03-29T20:45:00',
#   'utcDate': '2024-03-29T17:45:00Z',
#   'local': {'club': {'code': 'ULK',
#     'name': 'Fenerbahce Beko Istanbul',
#     'abbreviatedName': 'Fenerbahce',
#     'editorialName': 'Fenerbahce',
#     'tvCode': 'FBB',
#     'isVirtual': False,
#     'images': {'crest': 'https://media-cdn.incrowdsports.com/0233ebbb-f3a2-49ea-837c-7fd3e661e672.png'}},
#    'score': 0,
#    'standingsScore': 0,
#    'partials': {'partials1': 0,
#     'partials2': 0,
#     'partials3': 0,
#     'partials4': 0,
#     'extraPeriods': {}}},
#   'road': {'club': {'code': 'BER',
#     'name': 'ALBA Berlin',
#     'abbreviatedName': 'ALBA',
#     'editorialName': 'ALBA',
#     'tvCode': 'BER',
#     'isVirtual': False,
#     'images': {'crest': 'https://media-cdn.incrowdsports.com/ccc34858-22b0-47dc-904c-9940b0a16ff3.png'}},
#    'score': 0,
#    'standingsScore': 0,
#    'partials': {'partials1': 0,
#     'partials2': 0,
#     'partials3': 0,
#     'partials4': 0,
#     'extraPeriods': {}}},
#   'audience': 0,
#   'audienceConfirmed': False,
#   'socialFeed': '',
#   'operationsCode': None,
#   'referee1': None,
#   'referee2': None,
#   'referee3': None,
#   'referee4': None,
#   'venue': {'name': 'ULKER SPORTS AND EVENT HALL',
#    'code': 'AMY3',
#    'capacity': 13113,
#    'address': 'Barbaros Mah. Ihlamur Sok. Batı Ataşehir, 34764 Istanbul',
#    'images': {'medium': None},
#    'active': True,
#    'notes': ''},
#   'isNeutralVenue': False,
#   'gameStatus': 'Confirmed',
#   'winner': None},
#  {'gameCode': 281,
#   'season': {'name': 'EuroLeague 2023-24',
#    'code': 'E2023',
#    'alias': '2023-24',
#    'competitionCode': 'E',
#    'year': 2023,
#    'startDate': '2023-06-29T00:00:00'},
#   'group': {'id': '1c8d3521-392b-4637-8aea-7b35f797bbba',
#    'order': 1,
#    'name': 'Group Regular Season',
#    'rawName': 'Regular Season'},
#   'phaseType': {'code': 'RS',
#    'alias': 'REGULAR SEASON',
#    'name': 'Regular Season',
#    'isGroupPhase': True},
#   'round': 32,
#   'roundAlias': 'Round 32',
#   'roundName': 'Round 32',
#   'played': False,
#   'date': '2024-03-28T21:00:00',
#   'confirmedDate': True,
#   'confirmedHour': True,
#   'localTimeZone': 1,
#   'localDate': '2024-03-28T21:00:00',
#   'utcDate': '2024-03-28T20:00:00Z',
#   'local': {'club': {'code': 'ASV',
#     'name': 'LDLC ASVEL Villeurbanne',
#     'abbreviatedName': 'ASVEL',
#     'editorialName': 'ASVEL',
#     'tvCode': 'ASV',
#     'isVirtual': False,
#     'images': {'crest': 'https://media-cdn.incrowdsports.com/e33c6d1a-95ca-4dbc-b8cb-0201812104cc.png'}},
#    'score': 0,
#    'standingsScore': 0,
#    'partials': {'partials1': 0,
#     'partials2': 0,
#     'partials3': 0,
#     'partials4': 0,
#     'extraPeriods': {}}},
#   'road': {'club': {'code': 'MCO',
#     'name': 'AS Monaco',
#     'abbreviatedName': 'Monaco',
#     'editorialName': 'Monaco',
#     'tvCode': 'ASM',
#     'isVirtual': False,
#     'images': {'crest': 'https://media-cdn.incrowdsports.com/89ed276a-2ba3-413f-8ea2-b3be209ca129.png'}},
#    'score': 0,
#    'standingsScore': 0,
#    'partials': {'partials1': 0,
#     'partials2': 0,
#     'partials3': 0,
#     'partials4': 0,
#     'extraPeriods': {}}},
#   'audience': 0,
#   'audienceConfirmed': False,
#   'socialFeed': '',
#   'operationsCode': None,
#   'referee1': None,
#   'referee2': None,
#   'referee3': None,
#   'referee4': None,
#   'venue': {'name': 'LDLC ARENA',
#    'code': 'AUZ1',
#    'capacity': 12523,
#    'address': '',
#    'images': {'medium': None},
#    'active': True,
#    'notes': ''},
#   'isNeutralVenue': False,
#   'gameStatus': 'Confirmed',
#   'winner': None},
#  {'gameCode': 284,
#   'season': {'name': 'EuroLeague 2023-24',
#    'code': 'E2023',
#    'alias': '2023-24',
#    'competitionCode': 'E',
#    'year': 2023,
#    'startDate': '2023-06-29T00:00:00'},
#   'group': {'id': '1c8d3521-392b-4637-8aea-7b35f797bbba',
#    'order': 1,
#    'name': 'Group Regular Season',
#    'rawName': 'Regular Season'},
#   'phaseType': {'code': 'RS',
#    'alias': 'REGULAR SEASON',
#    'name': 'Regular Season',
#    'isGroupPhase': True},
#   'round': 32,
#   'roundAlias': 'Round 32',
#   'roundName': 'Round 32',
#   'played': False,
#   'date': '2024-03-28T20:30:00',
#   'confirmedDate': True,
#   'confirmedHour': True,
#   'localTimeZone': 1,
#   'localDate': '2024-03-28T20:30:00',
#   'utcDate': '2024-03-28T19:30:00Z',
#   'local': {'club': {'code': 'PAR',
#     'name': 'Partizan Mozzart Bet Belgrade',
#     'abbreviatedName': 'Partizan',
#     'editorialName': 'Partizan',
#     'tvCode': 'PAR',
#     'isVirtual': False,
#     'images': {'crest': 'https://media-cdn.incrowdsports.com/2681304e-77dd-4331-88b1-683078c0fb49.png'}},
#    'score': 0,
#    'standingsScore': 0,
#    'partials': {'partials1': 0,
#     'partials2': 0,
#     'partials3': 0,
#     'partials4': 0,
#     'extraPeriods': {}}},
#   'road': {'club': {'code': 'OLY',
#     'name': 'Olympiacos Piraeus',
#     'abbreviatedName': 'Olympiacos',
#     'editorialName': 'Olympiacos',
#     'tvCode': 'OLY',
#     'isVirtual': False,
#     'images': {'crest': 'https://media-cdn.incrowdsports.com/789423ac-3cdf-4b89-b11c-b458aa5f59a6.png'}},
#    'score': 0,
#    'standingsScore': 0,
#    'partials': {'partials1': 0,
#     'partials2': 0,
#     'partials3': 0,
#     'partials4': 0,
#     'extraPeriods': {}}},
#   'audience': 0,
#   'audienceConfirmed': False,
#   'socialFeed': '',
#   'operationsCode': None,
#   'referee1': None,
#   'referee2': None,
#   'referee3': None,
#   'referee4': None,
#   'venue': {'name': 'STARK ARENA',
#    'code': 'ATM6',
#    'capacity': 20094,
#    'address': 'Bulevar Arsenija Carnojevica 58, 11070 Belgrade - Serbia',
#    'images': {'medium': None},
#    'active': True,
#    'notes': ''},
#   'isNeutralVenue': False,
#   'gameStatus': 'Confirmed',
#   'winner': None},
#  {'gameCode': 282,
#   'season': {'name': 'EuroLeague 2023-24',
#    'code': 'E2023',
#    'alias': '2023-24',
#    'competitionCode': 'E',
#    'year': 2023,
#    'startDate': '2023-06-29T00:00:00'},
#   'group': {'id': '1c8d3521-392b-4637-8aea-7b35f797bbba',
#    'order': 1,
#    'name': 'Group Regular Season',
#    'rawName': 'Regular Season'},
#   'phaseType': {'code': 'RS',
#    'alias': 'REGULAR SEASON',
#    'name': 'Regular Season',
#    'isGroupPhase': True},
#   'round': 32,
#   'roundAlias': 'Round 32',
#   'roundName': 'Round 32',
#   'played': False,
#   'date': '2024-03-28T20:30:00',
#   'confirmedDate': True,
#   'confirmedHour': True,
#   'localTimeZone': 1,
#   'localDate': '2024-03-28T20:30:00',
#   'utcDate': '2024-03-28T19:30:00Z',
#   'local': {'club': {'code': 'BAS',
# ...
#    'images': {'medium': None},
#    'active': True,
#    'notes': ''},
#   'isNeutralVenue': False,
#   'gameStatus': 'Confirmed',
#   'winner': None},
#  {'gameCode': 6,
#   'season': {'name': 'EuroLeague 2023-24',
#    'code': 'E2023',
#    'alias': '2023-24',
#    'competitionCode': 'E',
#    'year': 2023,
#    'startDate': '2023-06-29T00:00:00'},
#   'group': {'id': '1c8d3521-392b-4637-8aea-7b35f797bbba',
#    'order': 1,
#    'name': 'Group Regular Season',
#    'rawName': 'Regular Season'},
#   'phaseType': {'code': 'RS',
#    'alias': 'REGULAR SEASON',
#    'name': 'Regular Season',
#    'isGroupPhase': True},
#   'round': 1,
#   'roundAlias': 'Round 1',
#   'roundName': 'Round 1',
#   'played': True,
#   'date': '2023-10-06T19:45:00',
#   'confirmedDate': True,
#   'confirmedHour': True,
#   'localTimeZone': 3,
#   'localDate': '2023-10-06T20:45:00',
#   'utcDate': '2023-10-06T17:45:00Z',
#   'local': {'club': {'code': 'ULK',
#     'name': 'Fenerbahce Beko Istanbul',
#     'abbreviatedName': 'Fenerbahce',
#     'editorialName': 'Fenerbahce',
#     'tvCode': 'FBB',
#     'isVirtual': False,
#     'images': {'crest': 'https://media-cdn.incrowdsports.com/0233ebbb-f3a2-49ea-837c-7fd3e661e672.png'}},
#    'score': 85,
#    'standingsScore': 76,
#    'partials': {'partials1': 19,
#     'partials2': 19,
#     'partials3': 24,
#     'partials4': 14,
#     'extraPeriods': {'1': 9}}},
#   'road': {'club': {'code': 'MIL',
#     'name': 'EA7 Emporio Armani Milan',
#     'abbreviatedName': 'Milan',
#     'editorialName': 'Milan',
#     'tvCode': 'EA7',
#     'isVirtual': False,
#     'images': {'crest': 'https://media-cdn.incrowdsports.com/8154f184-c61a-4e7f-b14d-9d802e35cb95.png'}},
#    'score': 82,
#    'standingsScore': 76,
#    'partials': {'partials1': 23,
#     'partials2': 12,
#     'partials3': 19,
#     'partials4': 22,
#     'extraPeriods': {'1': 6}}},
#   'audience': 10211,
#   'audienceConfirmed': True,
#   'socialFeed': '',
#   'operationsCode': None,
#   'referee1': {'code': 'OADJ',
#    'name': 'PUKL,SASA',
#    'alias': 'PUKL,S.',
#    'country': {'code': 'SLO', 'name': 'Slovenia'},
#    'images': {'verticalSmall': '8863itxgormdtqhs'},
#    'active': True},
#   'referee2': {'code': 'OJIZ',
#    'name': 'PERUGA, CARLOS',
#    'alias': 'PERUGA, C.',
#    'country': {'code': 'ESP', 'name': 'Spain'},
#    'images': {'verticalSmall': '885qkoqdo5npvomj'},
#    'active': True},
#   'referee3': {'code': 'QJLS',
#    'name': 'NIKOLIC, UROS',
#    'alias': 'NIKOLIC, U.',
#    'country': {'code': 'SRB', 'name': 'Serbia'},
#    'images': {'verticalSmall': '94qpquklfn5tseb9'},
#    'active': True},
#   'referee4': None,
#   'venue': {'name': 'ULKER SPORTS AND EVENT HALL',
#    'code': 'AMY3',
#    'capacity': 13113,
#    'address': 'Barbaros Mah. Ihlamur Sok. Batı Ataşehir, 34764 Istanbul',
#    'images': {'medium': None},
#    'active': True,
#    'notes': ''},
#   'isNeutralVenue': False,
#   'gameStatus': 'Confirmed',
#   'winner': None},
#  {'gameCode': 5,
#   'season': {'name': 'EuroLeague 2023-24',
#    'code': 'E2023',
#    'alias': '2023-24',
#    'competitionCode': 'E',
#    'year': 2023,
#    'startDate': '2023-06-29T00:00:00'},
#   'group': {'id': '1c8d3521-392b-4637-8aea-7b35f797bbba',
#    'order': 1,
#    'name': 'Group Regular Season',
#    'rawName': 'Regular Season'},
#   'phaseType': {'code': 'RS',
#    'alias': 'REGULAR SEASON',
#    'name': 'Regular Season',
#    'isGroupPhase': True},
#   'round': 1,
#   'roundAlias': 'Round 1',
#   'roundName': 'Round 1',
#   'played': True,
#   'date': '2023-10-05T20:30:00',
#   'confirmedDate': True,
#   'confirmedHour': True,
#   'localTimeZone': 2,
#   'localDate': '2023-10-05T20:30:00',
#   'utcDate': '2023-10-05T18:30:00Z',
#   'local': {'club': {'code': 'VIR',
#     'name': 'Virtus Segafredo Bologna',
#     'abbreviatedName': 'Virtus',
#     'editorialName': 'Virtus',
#     'tvCode': 'VIR',
#     'isVirtual': False,
#     'images': {'crest': 'https://media-cdn.incrowdsports.com/4af5e83b-f2b5-4fba-a87c-1f85837a508a.png'}},
#    'score': 79,
#    'standingsScore': 79,
#    'partials': {'partials1': 23,
#     'partials2': 19,
#     'partials3': 23,
#     'partials4': 14,
#     'extraPeriods': {}}},
#   'road': {'club': {'code': 'ZAL',
#     'name': 'Zalgiris Kaunas',
#     'abbreviatedName': 'Zalgiris',
#     'editorialName': 'Zalgiris',
#     'tvCode': 'ZAL',
#     'isVirtual': False,
#     'images': {'crest': 'https://media-cdn.incrowdsports.com/0aa09358-3847-4c4e-b228-3582ee4e536d.png'}},
#    'score': 82,
#    'standingsScore': 82,
#    'partials': {'partials1': 15,
#     'partials2': 22,
#     'partials3': 21,
#     'partials4': 24,
#     'extraPeriods': {}}},
#   'audience': 4437,
#   'audienceConfirmed': True,
#   'socialFeed': '',
#   'operationsCode': None,
#   'referee1': {'code': 'OJBD',
#    'name': 'BOLTAUZER, MATEJ',
#    'alias': 'BOLTAUZER, M.',
#    'country': {'code': 'SLO', 'name': 'Slovenia'},
#    'images': {'verticalSmall': 'ayromitbfytdbdk7'},
#    'active': True},
#   'referee2': {'code': 'OJLJ',
#    'name': 'PANTHER, ANNE',
#    'alias': 'PANTHER, A.',
#    'country': {'code': 'GER', 'name': 'Germany'},
#    'images': {'verticalSmall': '885wcxfmwtcvkvfd'},
#    'active': True},
#   'referee3': {'code': 'OJFU',
#    'name': 'SILVA, SERGIO',
#    'alias': 'SILVA, S.',
#    'country': {'code': 'POR', 'name': 'Portugal'},
#    'images': {'verticalSmall': '88694sdmpnbwjska'},
#    'active': True},
#   'referee4': None,
#   'venue': {'name': 'PALADOZZA',
#    'code': 'AIG',
#    'capacity': 5570,
#    'address': 'Via Nannetti 1, 40122 Bologna - Italy',
#    'images': {'medium': None},
#    'active': True,
#    'notes': ''},
#   'isNeutralVenue': False,
#   'gameStatus': 'Confirmed',
#   'winner': None},
#  {'gameCode': 3,
#   'season': {'name': 'EuroLeague 2023-24',
#    'code': 'E2023',
#    'alias': '2023-24',
#    'competitionCode': 'E',
#    'year': 2023,
#    'startDate': '2023-06-29T00:00:00'},
#   'group': {'id': '1c8d3521-392b-4637-8aea-7b35f797bbba',
#    'order': 1,
#    'name': 'Group Regular Season',
#    'rawName': 'Regular Season'},
#   'phaseType': {'code': 'RS',
#    'alias': 'REGULAR SEASON',
#    'name': 'Regular Season',
#    'isGroupPhase': True},
#   'round': 1,
#   'roundAlias': 'Round 1',
#   'roundName': 'Round 1',
#   'played': True,
#   'date': '2023-10-05T20:30:00',
#   'confirmedDate': True,
#   'confirmedHour': True,
#   'localTimeZone': 2,
#   'localDate': '2023-10-05T20:30:00',
#   'utcDate': '2023-10-05T18:30:00Z',
#   'local': {'club': {'code': 'MUN',
#     'name': 'FC Bayern Munich',
#     'abbreviatedName': 'Bayern',
#     'editorialName': 'Bayern',
#     'tvCode': 'BAY',
#     'isVirtual': False,
#     'images': {'crest': 'https://media-cdn.incrowdsports.com/817b0e58-d595-4b09-ab0b-1e7cc26249ff.png'}},
#    'score': 80,
#    'standingsScore': 80,
#    'partials': {'partials1': 19,
#     'partials2': 17,
#     'partials3': 25,
#     'partials4': 19,
#     'extraPeriods': {}}},
#   'road': {'club': {'code': 'BER',
#     'name': 'ALBA Berlin',
#     'abbreviatedName': 'ALBA',
#     'editorialName': 'ALBA',
#     'tvCode': 'BER',
#     'isVirtual': False,
#     'images': {'crest': 'https://media-cdn.incrowdsports.com/ccc34858-22b0-47dc-904c-9940b0a16ff3.png'}},
#    'score': 68,
#    'standingsScore': 68,
#    'partials': {'partials1': 17,
#     'partials2': 27,
#     'partials3': 7,
#     'partials4': 17,
#     'extraPeriods': {}}},
#   'audience': 6057,
#   'audienceConfirmed': True,
#   'socialFeed': '',
#   'operationsCode': None,
#   'referee1': {'code': 'OAEF',
#    'name': 'GARCIA, JUAN CARLOS',
#    'alias': 'GARCIA GONZALEZ, J.C.',
#    'country': {'code': 'ESP', 'name': 'Spain'},
#    'images': {'verticalSmall': '883ghgjot7u5suil'},
#    'active': True},
#   'referee2': {'code': 'OJDF',
#    'name': 'LATISEVS, OLEGS',
#    'alias': 'LATISEVS, O.',
#    'country': {'code': 'LAT', 'name': 'Latvia'},
#    'images': {'verticalSmall': '8845j7vs5indngbw'},
#    'active': True},
#   'referee3': {'code': 'OJLP',
#    'name': 'SUKYS, ARTURAS',
#    'alias': 'SUKYS, A.',
#    'country': {'code': 'LTU', 'name': 'Lithuania'},
#    'images': {'verticalSmall': '89oview3i6xl9tp4'},
#    'active': True},
#   'referee4': None,
#   'venue': {'name': 'BMW PARK',
#    'code': 'AMV1',
#    'capacity': 6534,
#    'address': 'Grasweg 74, 81373 Munich',
#    'images': {'medium': None},
#    'active': True,
#    'notes': ''},
#   'isNeutralVenue': False,
#   'gameStatus': 'Confirmed',
#   'winner': None},
#  {'gameCode': 2,
#   'season': {'name': 'EuroLeague 2023-24',
#    'code': 'E2023',
#    'alias': '2023-24',
#    'competitionCode': 'E',
#    'year': 2023,
#    'startDate': '2023-06-29T00:00:00'},
#   'group': {'id': '1c8d3521-392b-4637-8aea-7b35f797bbba',
#    'order': 1,
#    'name': 'Group Regular Season',
#    'rawName': 'Regular Season'},
#   'phaseType': {'code': 'RS',
#    'alias': 'REGULAR SEASON',
#    'name': 'Regular Season',
#    'isGroupPhase': True},
#   'round': 1,
#   'roundAlias': 'Round 1',
#   'roundName': 'Round 1',
#   'played': True,
#   'date': '2023-10-05T20:30:00',
#   'confirmedDate': True,
#   'confirmedHour': True,
#   'localTimeZone': 2,
#   'localDate': '2023-10-05T20:30:00',
#   'utcDate': '2023-10-05T18:30:00Z',
#   'local': {'club': {'code': 'BAR',
#     'name': 'FC Barcelona',
#     'abbreviatedName': 'Barcelona',
#     'editorialName': 'Barcelona',
#     'tvCode': 'BAR',
#     'isVirtual': False,
#     'images': {'crest': 'https://media-cdn.incrowdsports.com/35dfa503-e417-481f-963a-bdf6f013763e.png'}},
#    'score': 91,
#    'standingsScore': 91,
#    'partials': {'partials1': 22,
#     'partials2': 18,
#     'partials3': 29,
#     'partials4': 22,
#     'extraPeriods': {}}},
#   'road': {'club': {'code': 'IST',
#     'name': 'Anadolu Efes Istanbul',
#     'abbreviatedName': 'Efes',
#     'editorialName': 'Efes',
#     'tvCode': 'EFS',
#     'isVirtual': False,
#     'images': {'crest': 'https://media-cdn.incrowdsports.com/8ea8cec7-d8f7-45f4-a956-d976b5867610.png'}},
#    'score': 74,
#    'standingsScore': 74,
#    'partials': {'partials1': 19,
#     'partials2': 15,
#     'partials3': 30,
#     'partials4': 10,
#     'extraPeriods': {}}},
#   'audience': 5577,
#   'audienceConfirmed': True,
#   'socialFeed': '',
#   'operationsCode': None,
#   'referee1': {'code': 'OJCZ',
#    'name': 'RADOVIC, SRETEN',
#    'alias': 'RADOVIC, S.',
#    'country': {'code': 'CRO', 'name': 'Croatia'},
#    'images': {'verticalSmall': '8864r3sdiwfigeb9'},
#    'active': True},
#   'referee2': {'code': 'OJLL',
#    'name': 'DIFALLAH, MEHDI',
#    'alias': 'DIFALLAH, M.',
#    'country': {'code': 'FRA', 'name': 'France'},
#    'images': {'verticalSmall': '87ytu4ivn6qtsqni'},
#    'active': True},
#   'referee3': {'code': 'OACY',
#    'name': 'JOVCIC, MILIVOJE',
#    'alias': 'JOVCIC, M.',
#    'country': {'code': 'SRB', 'name': 'Serbia'},
#    'images': {'verticalSmall': '8844kualjiu9jr5p'},
#    'active': True},
#   'referee4': None,
#   'venue': {'name': 'PALAU BLAUGRANA',
#    'code': 'AMH3',
#    'capacity': 7786,
#    'address': 'Aristides Maillol Av S/N, 08028 Barcelona',
#    'images': {'medium': None},
#    'active': True,
#    'notes': ''},
#   'isNeutralVenue': False,
#   'gameStatus': 'Confirmed',
#   'winner': None},
#  {'gameCode': 4,
#   'season': {'name': 'EuroLeague 2023-24',
#    'code': 'E2023',
#    'alias': '2023-24',
#    'competitionCode': 'E',
#    'year': 2023,
#    'startDate': '2023-06-29T00:00:00'},
#   'group': {'id': '1c8d3521-392b-4637-8aea-7b35f797bbba',
#    'order': 1,
#    'name': 'Group Regular Season',
#    'rawName': 'Regular Season'},
#   'phaseType': {'code': 'RS',
#    'alias': 'REGULAR SEASON',
#    'name': 'Regular Season',
#    'isGroupPhase': True},
#   'round': 1,
#   'roundAlias': 'Round 1',
#   'roundName': 'Round 1',
#   'played': True,
#   'date': '2023-10-05T20:05:00',
#   'confirmedDate': True,
#   'confirmedHour': True,
#   'localTimeZone': 3,
#   'localDate': '2023-10-05T21:05:00',
#   'utcDate': '2023-10-05T18:05:00Z',
#   'local': {'club': {'code': 'TEL',
#     'name': 'Maccabi Playtika Tel Aviv',
#     'abbreviatedName': 'Maccabi',
#     'editorialName': 'Maccabi',
#     'tvCode': 'MTA',
#     'isVirtual': False,
#     'images': {'crest': 'https://media-cdn.incrowdsports.com/5c55ef14-29df-4328-bd52-a7a64c432350.png'}},
#    'score': 96,
#    'standingsScore': 96,
#    'partials': {'partials1': 27,
#     'partials2': 28,
#     'partials3': 19,
#     'partials4': 22,
#     'extraPeriods': {}}},
#   'road': {'club': {'code': 'PAR',
#     'name': 'Partizan Mozzart Bet Belgrade',
#     'abbreviatedName': 'Partizan',
#     'editorialName': 'Partizan',
#     'tvCode': 'PAR',
#     'isVirtual': False,
#     'images': {'crest': 'https://media-cdn.incrowdsports.com/2681304e-77dd-4331-88b1-683078c0fb49.png'}},
#    'score': 81,
#    'standingsScore': 81,
#    'partials': {'partials1': 16,
#     'partials2': 27,
#     'partials3': 15,
#     'partials4': 23,
#     'extraPeriods': {}}},
#   'audience': 10559,
#   'audienceConfirmed': True,
#   'socialFeed': '',
#   'operationsCode': None,
#   'referee1': {'code': 'OAEN',
#    'name': 'PEREZ, MIGUEL ANGEL',
#    'alias': 'PEREZ, M.',
#    'country': {'code': 'ESP', 'name': 'Spain'},
#    'images': {'verticalSmall': '885xtwkcapuckeov'},
#    'active': True},
#   'referee2': {'code': 'QJLV',
#    'name': 'VILIUS, GYTIS',
#    'alias': 'VILIUS, G.',
#    'country': {'code': 'LTU', 'name': 'Lithuania'},
#    'images': {'verticalSmall': '94qq99ojsab3pjud'},
#    'active': True},
#   'referee3': {'code': 'QJMF',
#    'name': 'KARDUM, LUKA',
#    'alias': 'KARDUM, L.',
#    'country': {'code': 'CRO', 'name': 'Croatia'},
#    'images': {'verticalSmall': 'awgpghekyaxank3l'},
#    'active': True},
#   'referee4': None,
#   'venue': {'name': 'MENORA MIVTACHIM ARENA',
#    'code': 'AQO',
#    'capacity': 11192,
#    'address': '51, Igal Alon, 67062 Tel Aviv',
#    'images': {'medium': None},
#    'active': True,
#    'notes': ''},
#   'isNeutralVenue': False,
#   'gameStatus': 'Confirmed',
#   'winner': None},
#  {'gameCode': 1,
#   'season': {'name': 'EuroLeague 2023-24',
#    'code': 'E2023',
#    'alias': '2023-24',
#    'competitionCode': 'E',
#    'year': 2023,
#    'startDate': '2023-06-29T00:00:00'},
#   'group': {'id': '1c8d3521-392b-4637-8aea-7b35f797bbba',
#    'order': 1,
#    'name': 'Group Regular Season',
#    'rawName': 'Regular Season'},
#   'phaseType': {'code': 'RS',
#    'alias': 'REGULAR SEASON',
#    'name': 'Regular Season',
#    'isGroupPhase': True},
#   'round': 1,
#   'roundAlias': 'Round 1',
#   'roundName': 'Round 1',
#   'played': True,
#   'date': '2023-10-05T19:00:00',
#   'confirmedDate': True,
#   'confirmedHour': True,
#   'localTimeZone': 2,
#   'localDate': '2023-10-05T19:00:00',
#   'utcDate': '2023-10-05T17:00:00Z',
#   'local': {'club': {'code': 'RED',
#     'name': 'Crvena Zvezda Meridianbet Belgrade',
#     'abbreviatedName': 'Zvezda',
#     'editorialName': 'Crvena Zvezda',
#     'tvCode': 'CZV',
#     'isVirtual': False,
#     'images': {'crest': 'https://media-cdn.incrowdsports.com/d2eef4a8-62df-4fdd-9076-276004268515.png'}},
#    'score': 94,
#    'standingsScore': 94,
#    'partials': {'partials1': 29,
#     'partials2': 23,
#     'partials3': 17,
#     'partials4': 25,
#     'extraPeriods': {}}},
#   'road': {'club': {'code': 'ASV',
#     'name': 'LDLC ASVEL Villeurbanne',
#     'abbreviatedName': 'ASVEL',
#     'editorialName': 'ASVEL',
#     'tvCode': 'ASV',
#     'isVirtual': False,
#     'images': {'crest': 'https://media-cdn.incrowdsports.com/e33c6d1a-95ca-4dbc-b8cb-0201812104cc.png'}},
#    'score': 73,
#    'standingsScore': 73,
#    'partials': {'partials1': 18,
#     'partials2': 13,
#     'partials3': 24,
#     'partials4': 18,
#     'extraPeriods': {}}},
#   'audience': 18360,
#   'audienceConfirmed': True,
#   'socialFeed': '',
#   'operationsCode': None,
#   'referee1': {'code': 'OABC',
#    'name': 'ROCHA, FERNANDO',
#    'alias': 'ROCHA, F.',
#    'country': {'code': 'POR', 'name': 'Portugal'},
#    'images': {'verticalSmall': '88654j47f8j5rrkt'},
#    'active': True},
#   'referee2': {'code': 'OAEM',
#    'name': 'PATERNICO, CARMELO',
#    'alias': 'PATERNICO, C.',
#    'country': {'code': 'ITA', 'name': 'Italy'},
#    'images': {'verticalSmall': '885x49q73ymq7gg3'},
#    'active': True},
#   'referee3': {'code': 'OJIY',
#    'name': 'PASTUSIAK, PIOTR',
#    'alias': 'PASTUSIAK, P.',
#    'country': {'code': 'POL', 'name': 'Poland'},
#    'images': {'verticalSmall': '885wrb4rki89jxa3'},
#    'active': True},
#   'referee4': None,
#   'venue': {'name': 'STARK ARENA',
#    'code': 'ATM6',
#    'capacity': 20094,
#    'address': 'Bulevar Arsenija Carnojevica 58, 11070 Belgrade - Serbia',
#    'images': {'medium': None},
#    'active': True,
#    'notes': ''},
#   'isNeutralVenue': False,
#   'gameStatus': 'Confirmed',
#   'winner': None}]

# %%
data["data"][300]
# Out:
# {'gameCode': 6,
#  'season': {'name': 'EuroLeague 2023-24',
#   'code': 'E2023',
#   'alias': '2023-24',
#   'competitionCode': 'E',
#   'year': 2023,
#   'startDate': '2023-06-29T00:00:00'},
#  'group': {'id': '1c8d3521-392b-4637-8aea-7b35f797bbba',
#   'order': 1,
#   'name': 'Group Regular Season',
#   'rawName': 'Regular Season'},
#  'phaseType': {'code': 'RS',
#   'alias': 'REGULAR SEASON',
#   'name': 'Regular Season',
#   'isGroupPhase': True},
#  'round': 1,
#  'roundAlias': 'Round 1',
#  'roundName': 'Round 1',
#  'played': True,
#  'date': '2023-10-06T19:45:00',
#  'confirmedDate': True,
#  'confirmedHour': True,
#  'localTimeZone': 3,
#  'localDate': '2023-10-06T20:45:00',
#  'utcDate': '2023-10-06T17:45:00Z',
#  'local': {'club': {'code': 'ULK',
#    'name': 'Fenerbahce Beko Istanbul',
#    'abbreviatedName': 'Fenerbahce',
#    'editorialName': 'Fenerbahce',
#    'tvCode': 'FBB',
#    'isVirtual': False,
#    'images': {'crest': 'https://media-cdn.incrowdsports.com/0233ebbb-f3a2-49ea-837c-7fd3e661e672.png'}},
#   'score': 85,
#   'standingsScore': 76,
#   'partials': {'partials1': 19,
#    'partials2': 19,
#    'partials3': 24,
#    'partials4': 14,
#    'extraPeriods': {'1': 9}}},
#  'road': {'club': {'code': 'MIL',
#    'name': 'EA7 Emporio Armani Milan',
#    'abbreviatedName': 'Milan',
#    'editorialName': 'Milan',
#    'tvCode': 'EA7',
#    'isVirtual': False,
#    'images': {'crest': 'https://media-cdn.incrowdsports.com/8154f184-c61a-4e7f-b14d-9d802e35cb95.png'}},
#   'score': 82,
#   'standingsScore': 76,
#   'partials': {'partials1': 23,
#    'partials2': 12,
#    'partials3': 19,
#    'partials4': 22,
#    'extraPeriods': {'1': 6}}},
#  'audience': 10211,
#  'audienceConfirmed': True,
#  'socialFeed': '',
#  'operationsCode': None,
#  'referee1': {'code': 'OADJ',
#   'name': 'PUKL,SASA',
#   'alias': 'PUKL,S.',
#   'country': {'code': 'SLO', 'name': 'Slovenia'},
#   'images': {'verticalSmall': '8863itxgormdtqhs'},
#   'active': True},
#  'referee2': {'code': 'OJIZ',
#   'name': 'PERUGA, CARLOS',
#   'alias': 'PERUGA, C.',
#   'country': {'code': 'ESP', 'name': 'Spain'},
#   'images': {'verticalSmall': '885qkoqdo5npvomj'},
#   'active': True},
#  'referee3': {'code': 'QJLS',
#   'name': 'NIKOLIC, UROS',
#   'alias': 'NIKOLIC, U.',
#   'country': {'code': 'SRB', 'name': 'Serbia'},
#   'images': {'verticalSmall': '94qpquklfn5tseb9'},
#   'active': True},
#  'referee4': None,
#  'venue': {'name': 'ULKER SPORTS AND EVENT HALL',
#   'code': 'AMY3',
#   'capacity': 13113,
#   'address': 'Barbaros Mah. Ihlamur Sok. Batı Ataşehir, 34764 Istanbul',
#   'images': {'medium': None},
#   'active': True,
#   'notes': ''},
#  'isNeutralVenue': False,
#  'gameStatus': 'Confirmed',
#  'winner': None}

# %%
data["data"][300].keys()
# Out:
# dict_keys(['gameCode', 'season', 'group', 'phaseType', 'round', 'roundAlias', 'roundName', 'played', 'date', 'confirmedDate', 'confirmedHour', 'localTimeZone', 'localDate', 'utcDate', 'local', 'road', 'audience', 'audienceConfirmed', 'socialFeed', 'operationsCode', 'referee1', 'referee2', 'referee3', 'referee4', 'venue', 'isNeutralVenue', 'gameStatus', 'winner'])

# %%
data["data"][300]["date"]
# Out:
# '2023-10-06T19:45:00'

# %%
data["data"][300]["local"]       # That's another dictionnaire (with nested dictionnaires)!!!!!
# Out:
# {'club': {'code': 'ULK',
#   'name': 'Fenerbahce Beko Istanbul',
#   'abbreviatedName': 'Fenerbahce',
#   'editorialName': 'Fenerbahce',
#   'tvCode': 'FBB',
#   'isVirtual': False,
#   'images': {'crest': 'https://media-cdn.incrowdsports.com/0233ebbb-f3a2-49ea-837c-7fd3e661e672.png'}},
#  'score': 85,
#  'standingsScore': 76,
#  'partials': {'partials1': 19,
#   'partials2': 19,
#   'partials3': 24,
#   'partials4': 14,
#   'extraPeriods': {'1': 9}}}

# %%
data["data"][300]["road"]       # That's another dictionnaire (with nested dictionnaires)!!!!!
# Out:
# {'club': {'code': 'MIL',
#   'name': 'EA7 Emporio Armani Milan',
#   'abbreviatedName': 'Milan',
#   'editorialName': 'Milan',
#   'tvCode': 'EA7',
#   'isVirtual': False,
#   'images': {'crest': 'https://media-cdn.incrowdsports.com/8154f184-c61a-4e7f-b14d-9d802e35cb95.png'}},
#  'score': 82,
#  'standingsScore': 76,
#  'partials': {'partials1': 23,
#   'partials2': 12,
#   'partials3': 19,
#   'partials4': 22,
#   'extraPeriods': {'1': 6}}}

# %%
data["data"][290]["road"]       # Keys can vary (more or less) depending on the index run!!!!!
# Out:
# {'club': {'code': 'BAR',
#   'name': 'FC Barcelona',
#   'abbreviatedName': 'Barcelona',
#   'editorialName': 'Barcelona',
#   'tvCode': 'BAR',
#   'isVirtual': False,
#   'images': {'crest': 'https://media-cdn.incrowdsports.com/35dfa503-e417-481f-963a-bdf6f013763e.png'}},
#  'score': 77,
#  'standingsScore': 77,
#  'partials': {'partials1': 23,
#   'partials2': 17,
#   'partials3': 16,
#   'partials4': 21,
#   'extraPeriods': {}}}

# %%
data["data"][290]["referee1"]
# Out:
# {'code': 'OADJ',
#  'name': 'PUKL,SASA',
#  'alias': 'PUKL,S.',
#  'country': {'code': 'SLO', 'name': 'Slovenia'},
#  'images': {'verticalSmall': '8863itxgormdtqhs'},
#  'active': True}

# %% [markdown]
# ### We will need to extract our information step by step!
# #### Before trying to extract everything and then filtering the data, we will do the other way around: What are the basic columns that we must obtain from this json file?
# - fecha
# - ronda
# - local
# - localscore
# - road
# - roadscore
# - arbitros(list)

# %%
# Explore the df to know exactly where the useful info is
data["data"][300]["roundName"]
# Out:
# 'Round 1'

# %% [markdown]
# #### Now that we have everythin that we need, it is time to extract it and save it in lists!

# %%
fecha=[]
ronda=[]
local=[]
localscore=[]
road=[]
roadscore=[]
arbitros=[[]for i in range(len(data["data"]))]       # It's also an empty list, but the total referees are 4!!!!!

# %%
count=0
for i in data["data"]:
    fecha.append(i["date"])
    ronda.append(i["round"])
    local.append(i["local"]["club"]["name"])
    localscore.append(i["local"]["score"])
    road.append(i["road"]["club"]["name"])
    roadscore.append(i["road"]["score"])
    if i["local"]["score"]>0:
        for k in range(3):
            arbitros[count].append(i[f"referee{k+1}"]["name"])
    count+=1

# %% [markdown]
# #### Let's now save it as a DataFrame

# %%
tabla=pd.DataFrame({"Fecha": fecha, 
                    "Ronda": ronda, 
                    "Local": local, 
                    "Visitante": road, 
                    "Arbitros": arbitros, 
                    "Localscore": localscore,
                    "Roadscore": roadscore})

# %% [markdown]
# #### Is there any problem when looking at the .head of the data? Is it normal?

# %%
tabla.head()
# Out:
#                  Fecha  Ronda                          Local  \
# 0  2024-04-12T21:00:00     34        LDLC ASVEL Villeurbanne
# 1  2024-04-12T20:30:00     34  Partizan Mozzart Bet Belgrade
# 2  2024-04-12T20:30:00     34       Virtus Segafredo Bologna
# 3  2024-04-12T20:15:00     34             Olympiacos Piraeus
# 4  2024-04-11T20:15:00     34     Panathinaikos AKTOR Athens
#
#                   Visitante Arbitros  Localscore  Roadscore
# 0              FC Barcelona       []           0          0
# 1           Valencia Basket       []           0          0
# 2  Baskonia Vitoria-Gasteiz       []           0          0
# 3  Fenerbahce Beko Istanbul       []           0          0
# 4               ALBA Berlin       []           0          0

# %% [markdown]
# #### Try the info and describe methods. Is any of them not the thing we are expecting?
# tik, tak

# %%
tabla.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 306 entries, 0 to 305
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Fecha       306 non-null    object
#  1   Ronda       306 non-null    int64
#  2   Local       306 non-null    object
#  3   Visitante   306 non-null    object
#  4   Arbitros    306 non-null    object
#  5   Localscore  306 non-null    int64
#  6   Roadscore   306 non-null    int64
# dtypes: int64(3), object(4)
# memory usage: 16.9+ KB

# %%
tabla.Fecha=pd.to_datetime(tabla.Fecha)

# %%
tabla.info()       # Notice that Dtype for 'Fecha' has changed!!!!!
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 306 entries, 0 to 305
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Fecha       306 non-null    datetime64[ns]
#  1   Ronda       306 non-null    int64
#  2   Local       306 non-null    object
#  3   Visitante   306 non-null    object
#  4   Arbitros    306 non-null    object
#  5   Localscore  306 non-null    int64
#  6   Roadscore   306 non-null    int64
# dtypes: datetime64[ns](1), int64(3), object(3)
# memory usage: 16.9+ KB

# %%
tabla['Dia'] = tabla['Fecha'].map(lambda x: str(x)[:10])       # This way, dates & times are treated as strings!!!!!
tabla['Hora'] = tabla['Fecha'].map(lambda x: str(x)[11:])

tabla['Dia'] = tabla['Fecha'].dt.strftime('%Y-%m-%d')       # Better to treat dates & times this way!!!!!
tabla['Hora'] = tabla['Fecha'].dt.strftime('%H:%M:%S')         # Keep in mind that '-' in 'dates' can vary depending on the format

# %% [markdown]
# #### Columns Addition: Competition and Phase

# %%
tabla["Competition"] = "EuroLeague"
tabla["Phase"] = "Regular Season"

# %%
tabla.sample()
# Out:
#      Ronda                  Local     Visitante  \
# 116     22  Anadolu Efes Istanbul  FC Barcelona
#
#                                               Arbitros  Localscore  Roadscore  \
# 116  [HORDOV, TOMISLAV , FOUFIS, IOANNIS, TSAROUCHA...          98         74
#
#             Dia      Hora Competititon           Phase Competition
# 116  2024-01-18  18:30:00   EuroLeague  Regular Season  EuroLeague

# %% [markdown]
# #### Column Drop: Any useless information?

# %%
tabla.drop(columns="Fecha", inplace=True)       # Let's imagine 'Fecha' is not needed
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 tabla.drop(columns="Fecha", inplace=True)
#
# File c:\Users\MIQUEL\anaconda3\envs\Original\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# File c:\Users\MIQUEL\anaconda3\envs\Original\Lib\site-packages\pandas\core\generic.py:4788, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786 for axis, labels in axes.items():
#    4787     if labels is not None:
# -> 4788         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4790 if inplace:
#    4791     self._update_inplace(obj)
#
# File c:\Users\MIQUEL\anaconda3\envs\Original\Lib\site-packages\pandas\core\generic.py:4830, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4828         new_axis = axis.drop(labels, level=level, errors=errors)
#    4829     else:
# -> 4830         new_axis = axis.drop(labels, errors=errors)
#    4831     indexer = axis.get_indexer(new_axis)
#    4833 # Case for non-unique axis
#    4834 else:
#
# File c:\Users\MIQUEL\anaconda3\envs\Original\Lib\site-packages\pandas\core\indexes\base.py:7070, in Index.drop(self, labels, errors)
#    7068 if mask.any():
#    7069     if errors != "ignore":
# -> 7070         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071     indexer = indexer[~mask]
#    7072 return self.delete(indexer)
#
# KeyError: "['Fecha'] not found in axis"

# %% [markdown]
# ### Rearranging the Columns: Any ideas?

# %%
tabla=tabla[['Competition', 'Phase', 'Ronda', 'Dia', 'Hora', 'Local', 'Visitante', 'Localscore', 'Roadscore','Arbitros' ]]

# %% [markdown]
# ### Now let's try to get rid of the matches without information: BRAINSTORMING

# %%
actual=tabla[tabla["Localscore"]>0]

# %%
actual.head()
# Out:
#    Competition           Phase  Ronda         Dia      Hora  \
# 81  EuroLeague  Regular Season     25  2024-02-02  20:30:00
# 82  EuroLeague  Regular Season     25  2024-02-02  20:30:00
# 83  EuroLeague  Regular Season     25  2024-02-02  20:00:00
# 84  EuroLeague  Regular Season     25  2024-02-02  19:00:00
# 85  EuroLeague  Regular Season     25  2024-02-02  18:30:00
#
#                                  Local                      Visitante  \
# 81            Virtus Segafredo Bologna  Partizan Mozzart Bet Belgrade
# 82                           AS Monaco       Fenerbahce Beko Istanbul
# 83  Crvena Zvezda Meridianbet Belgrade                   FC Barcelona
# 84                     Zalgiris Kaunas     Panathinaikos AKTOR Athens
# 85               Anadolu Efes Istanbul       EA7 Emporio Armani Milan
#
#     Localscore  Roadscore                                           Arbitros
# 81          88         84  [LOTTERMOSER, ROBERT, PUKL,SASA, TRAWICKI, TOM...
# 82          76         69       [JAVOR, DAMIR, FOUFIS, IOANNIS, BALAK, AMIT]
# 83          76         85  [ROCHA, FERNANDO, RACYS, SAULIUS, KONSTANTINOV...
# 84          80         68  [RADOVIC, SRETEN, PASTUSIAK, PIOTR, CORTES, CA...
# 85          79         73  [PEREZ, MIGUEL ANGEL, KARDUM, LUKA, BAENA, ALB...

# %%
actual.reset_index(inplace=True, drop=True)

# %%
actual.head()
# Out:
#   Competition           Phase  Ronda         Dia      Hora  \
# 0  EuroLeague  Regular Season     25  2024-02-02  20:30:00
# 1  EuroLeague  Regular Season     25  2024-02-02  20:30:00
# 2  EuroLeague  Regular Season     25  2024-02-02  20:00:00
# 3  EuroLeague  Regular Season     25  2024-02-02  19:00:00
# 4  EuroLeague  Regular Season     25  2024-02-02  18:30:00
#
#                                 Local                      Visitante  \
# 0            Virtus Segafredo Bologna  Partizan Mozzart Bet Belgrade
# 1                           AS Monaco       Fenerbahce Beko Istanbul
# 2  Crvena Zvezda Meridianbet Belgrade                   FC Barcelona
# 3                     Zalgiris Kaunas     Panathinaikos AKTOR Athens
# 4               Anadolu Efes Istanbul       EA7 Emporio Armani Milan
#
#    Localscore  Roadscore                                           Arbitros
# 0          88         84  [LOTTERMOSER, ROBERT, PUKL,SASA, TRAWICKI, TOM...
# 1          76         69       [JAVOR, DAMIR, FOUFIS, IOANNIS, BALAK, AMIT]
# 2          76         85  [ROCHA, FERNANDO, RACYS, SAULIUS, KONSTANTINOV...
# 3          80         68  [RADOVIC, SRETEN, PASTUSIAK, PIOTR, CORTES, CA...
# 4          79         73  [PEREZ, MIGUEL ANGEL, KARDUM, LUKA, BAENA, ALB...

# %%
actual["Plusminus"]=actual["Localscore"]-actual["Roadscore"]

# %%
actual.head()
# Out:
#   Competition           Phase  Ronda         Dia      Hora  \
# 0  EuroLeague  Regular Season     25  2024-02-02  20:30:00
# 1  EuroLeague  Regular Season     25  2024-02-02  20:30:00
# 2  EuroLeague  Regular Season     25  2024-02-02  20:00:00
# 3  EuroLeague  Regular Season     25  2024-02-02  19:00:00
# 4  EuroLeague  Regular Season     25  2024-02-02  18:30:00
#
#                                 Local                      Visitante  \
# 0            Virtus Segafredo Bologna  Partizan Mozzart Bet Belgrade
# 1                           AS Monaco       Fenerbahce Beko Istanbul
# 2  Crvena Zvezda Meridianbet Belgrade                   FC Barcelona
# 3                     Zalgiris Kaunas     Panathinaikos AKTOR Athens
# 4               Anadolu Efes Istanbul       EA7 Emporio Armani Milan
#
#    Localscore  Roadscore                                           Arbitros  \
# 0          88         84  [LOTTERMOSER, ROBERT, PUKL,SASA, TRAWICKI, TOM...
# 1          76         69       [JAVOR, DAMIR, FOUFIS, IOANNIS, BALAK, AMIT]
# 2          76         85  [ROCHA, FERNANDO, RACYS, SAULIUS, KONSTANTINOV...
# 3          80         68  [RADOVIC, SRETEN, PASTUSIAK, PIOTR, CORTES, CA...
# 4          79         73  [PEREZ, MIGUEL ANGEL, KARDUM, LUKA, BAENA, ALB...
#
#    Plusminus
# 0          4
# 1          7
# 2         -9
# 3         12
# 4          6

# %%
actual["Winner"]=np.where(actual["Plusminus"]>0, actual.Local, actual.Visitante)
                                #  Condition       If 'yes'        If 'no'

# %%
actual.head()
# Out:
#   Competition           Phase  Ronda         Dia      Hora  \
# 0  EuroLeague  Regular Season     25  2024-02-02  20:30:00
# 1  EuroLeague  Regular Season     25  2024-02-02  20:30:00
# 2  EuroLeague  Regular Season     25  2024-02-02  20:00:00
# 3  EuroLeague  Regular Season     25  2024-02-02  19:00:00
# 4  EuroLeague  Regular Season     25  2024-02-02  18:30:00
#
#                                 Local                      Visitante  \
# 0            Virtus Segafredo Bologna  Partizan Mozzart Bet Belgrade
# 1                           AS Monaco       Fenerbahce Beko Istanbul
# 2  Crvena Zvezda Meridianbet Belgrade                   FC Barcelona
# 3                     Zalgiris Kaunas     Panathinaikos AKTOR Athens
# 4               Anadolu Efes Istanbul       EA7 Emporio Armani Milan
#
#    Localscore  Roadscore                                           Arbitros  \
# 0          88         84  [LOTTERMOSER, ROBERT, PUKL,SASA, TRAWICKI, TOM...
# 1          76         69       [JAVOR, DAMIR, FOUFIS, IOANNIS, BALAK, AMIT]
# 2          76         85  [ROCHA, FERNANDO, RACYS, SAULIUS, KONSTANTINOV...
# 3          80         68  [RADOVIC, SRETEN, PASTUSIAK, PIOTR, CORTES, CA...
# 4          79         73  [PEREZ, MIGUEL ANGEL, KARDUM, LUKA, BAENA, ALB...
#
#    Plusminus                    Winner
# 0          4  Virtus Segafredo Bologna
# 1          7                 AS Monaco
# 2         -9              FC Barcelona
# 3         12           Zalgiris Kaunas
# 4          6     Anadolu Efes Istanbul

# %%
actual.rename(columns={"Winner": "Ganador"}, inplace=True)

# %%
actual.head()
# Out:
#   Competition           Phase  Ronda         Dia      Hora  \
# 0  EuroLeague  Regular Season     25  2024-02-02  20:30:00
# 1  EuroLeague  Regular Season     25  2024-02-02  20:30:00
# 2  EuroLeague  Regular Season     25  2024-02-02  20:00:00
# 3  EuroLeague  Regular Season     25  2024-02-02  19:00:00
# 4  EuroLeague  Regular Season     25  2024-02-02  18:30:00
#
#                                 Local                      Visitante  \
# 0            Virtus Segafredo Bologna  Partizan Mozzart Bet Belgrade
# 1                           AS Monaco       Fenerbahce Beko Istanbul
# 2  Crvena Zvezda Meridianbet Belgrade                   FC Barcelona
# 3                     Zalgiris Kaunas     Panathinaikos AKTOR Athens
# 4               Anadolu Efes Istanbul       EA7 Emporio Armani Milan
#
#    Localscore  Roadscore                                           Arbitros  \
# 0          88         84  [LOTTERMOSER, ROBERT, PUKL,SASA, TRAWICKI, TOM...
# 1          76         69       [JAVOR, DAMIR, FOUFIS, IOANNIS, BALAK, AMIT]
# 2          76         85  [ROCHA, FERNANDO, RACYS, SAULIUS, KONSTANTINOV...
# 3          80         68  [RADOVIC, SRETEN, PASTUSIAK, PIOTR, CORTES, CA...
# 4          79         73  [PEREZ, MIGUEL ANGEL, KARDUM, LUKA, BAENA, ALB...
#
#    Plusminus                   Ganador
# 0          4  Virtus Segafredo Bologna
# 1          7                 AS Monaco
# 2         -9              FC Barcelona
# 3         12           Zalgiris Kaunas
# 4          6     Anadolu Efes Istanbul

# %%
actual["Winner"]=np.where(actual["Ganador"]==actual["Local"], "Local", "Visitante")

# %% [markdown]
# ### Now, let's order the dataframe:
# - Should we order it depending on more than one column?
# - Will it affect the index?

# %%
actual.sort_values(["Ronda", "Dia", "Hora"], inplace=True)

# %%
actual.reset_index(inplace=True, drop=True)

# %%
actual.head(4)
# Out:
#   Competition           Phase  Ronda         Dia      Hora  \
# 0  EuroLeague  Regular Season      1  2023-10-05  19:00:00
# 1  EuroLeague  Regular Season      1  2023-10-05  20:05:00
# 2  EuroLeague  Regular Season      1  2023-10-05  20:30:00
# 3  EuroLeague  Regular Season      1  2023-10-05  20:30:00
#
#                                 Local                      Visitante  \
# 0  Crvena Zvezda Meridianbet Belgrade        LDLC ASVEL Villeurbanne
# 1           Maccabi Playtika Tel Aviv  Partizan Mozzart Bet Belgrade
# 2            Virtus Segafredo Bologna                Zalgiris Kaunas
# 3                    FC Bayern Munich                    ALBA Berlin
#
#    Localscore  Roadscore                                           Arbitros  \
# 0          94         73  [ROCHA, FERNANDO, PATERNICO, CARMELO, PASTUSIA...
# 1          96         81  [PEREZ, MIGUEL ANGEL, VILIUS, GYTIS, KARDUM, L...
# 2          79         82   [BOLTAUZER, MATEJ, PANTHER, ANNE, SILVA, SERGIO]
# 3          80         68  [GARCIA, JUAN CARLOS, LATISEVS, OLEGS, SUKYS, ...
#
#    Plusminus                             Ganador     Winner
# 0         21  Crvena Zvezda Meridianbet Belgrade      Local
# 1         15           Maccabi Playtika Tel Aviv      Local
# 2         -3                     Zalgiris Kaunas  Visitante
# 3         12                    FC Bayern Munich      Local

# %% [markdown]
# ### Addition of more columns (based on conditions):
#
# - +-
# - Winners of the matches

# %% [markdown]
# #### Rename of a particular column

# %% [markdown]
# #### What happens if we apply the np.where to a column that has already been created?

# %% [markdown]
# ## Questions about this basic DF
# - There has been more Local or Road winners?
# - Which club has won more matches?

# %% [markdown]
# ## Referees
#
# In this particular column, we could have some troubles as the object is not a string but a `list`
#
# We want to analyze:
#
# - How many referees has already been in a match?
# - Who is the referee that has been in more local victories?

# %% [markdown]
# ## Geolocalization: Map function
#
# Con este listado de países de la línea de más abajo, queremos asignar en cada row el país a cada uno de los equipos para saber dónde juega cada uno.
#
# Después, queremos analizar:
#
# - La media de puntos local y visitante por país
# - Cuál es el máximo de anotación local y visitante por país
# - El número de veces que han ganado los equipos locales en sus tierras, cuando jugaban de local

# %%
countries=["Serbia", "Israel", "Italy", "Germany", "Spain", "Turkey", "Greece", "Spain", "Spain", "Turkey","France", "Germany", "Lithuania", "France", "Greece", "Italy", "Serbia", "Spain"]

# %% [markdown]
# # Creation of the classification
#
# Now we are going to create the Final Classification:
#
# - What are the columns that we are going to use?
# - Is any transformation needed?
# - How can we operate with both local and Road teams?

# %% [markdown]
# # WE WILL SEE THIS IN THE LAB
# ## Let's compare the competitions!
#
# ![](https://eurospects.com/wp-content/uploads/2018/10/eurocupeuroleague.png)
